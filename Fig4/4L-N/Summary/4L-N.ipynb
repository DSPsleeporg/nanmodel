# %%
import os
import sys
import requests
from datetime import datetime 
from multiprocessing import Pool
import numpy as  np
import pandas as pd
from pathlib import Path
import pickle
from tqdm import tqdm
from time import time
from typing import Dict, List, Optional
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
plt.rcParams['font.family'] = 'Arial'

# %%
A0=[]
A1=[]
A2=[]
A3=[]
A4=[]
A5=[]
A6=[]
A7=[]


BBB=[ 'x_na', 'y_na', 'g_unav', 'g_cav', 'g_kvhh','g_nak','g_lena', 'g_lek']

S0 = pd.read_csv("OD0.csv")
T0 = pd.read_csv("OD10.csv")
S1 = pd.read_csv("OD1.csv")
T1 = pd.read_csv("OD11.csv")
S2 = pd.read_csv("OD2.csv")
T2 = pd.read_csv("OD12.csv")
S3 = pd.read_csv("OD3.csv")
T3 = pd.read_csv("OD13.csv")
S4 = pd.read_csv("OD4.csv")
T4 = pd.read_csv("OD14.csv")
S5 = pd.read_csv("OD5.csv")
T5 = pd.read_csv("OD15.csv")
S6 = pd.read_csv("OD6.csv")
T6 = pd.read_csv("OD16.csv")
S7 = pd.read_csv("OD7.csv")
T7 = pd.read_csv("OD17.csv")


for i in tqdm(range(len(S6["u1"]))):
    if(i==0):
        continue
    if (S6["u1"][i] == 0 or S6["u1"][i] == -1 or T6["u1"][i] == 0 or T6["d1"][i] == -1):
        continue
    A6.append((T6["u1"][i] + T6["d1"][i]) / (S6["u1"][i] + S6["d1"][i]))

for i in tqdm(range(len(S7["u1"]))):
    if(i==0):
        continue
    if (S7["u1"][i] == 0 or S7["u1"][i] == -1 or T7["u1"][i] == 0 or T7["d1"][i] == -1 or i>=len(S7["u1"])):
        continue
    A7.append((T7["u1"][i] + T7["d1"][i]) / (S7["u1"][i] + S7["d1"][i]))
    

for i in tqdm(range(len(S1["u1"]))):
    if(i==0):
        continue
    if (S1["u1"][i] == 0 or S1["u1"][i] == -1 or T1["u1"][i] == 0 or T1["d1"][i] == -1 or i>=len(S1["u1"])):
        continue
    A1.append((T1["u1"][i] + T1["d1"][i]) / (S1["u1"][i] + S1["d1"][i]))

for i in tqdm(range(len(S5["u1"]))):
    if(i==0):
        continue
    if (S5["u1"][i] == 0 or S5["u1"][i] == -1 or T5["u1"][i] == 0 or T5["d1"][i] == -1 or i>=len(S5["u1"])):
        continue
    A5.append((T5["u1"][i] + T5["d1"][i]) / (S5["u1"][i] + S5["d1"][i]))
    
for i in tqdm(range(len(S0["u1"]))):
    if(i==0):
        continue
    if (S0["u1"][i] == 0 or S0["u1"][i] == -1 or T0["u1"][i] == 0 or T0["d1"][i] == -1 or i>=len(S0["u1"])):
        continue
    A0.append((T0["u1"][i] + T0["d1"][i]) / (S0["u1"][i] + S0["d1"][i]))
    

for i in tqdm(range(len(S2["u1"]))):
    if(i==0):
        continue
    if (S2["u1"][i] == 0 or S2["u1"][i] == -1 or T2["u1"][i] == 0 or T2["d1"][i] == -1 or i>=len(S2["u1"])):
        continue
    A2.append((T2["u1"][i] + T2["d1"][i]) / (S2["u1"][i] + S2["d1"][i]))
    
for i in tqdm(range(len(S4["u1"]))):
    if(i==0):
        continue
    if (S4["u1"][i] == 0 or S4["u1"][i] == -1 or T4["u1"][i] == 0 or T4["d1"][i] == -1 or i>=len(S4["u1"])):
        continue
    A4.append((T4["u1"][i] + T4["d1"][i]) / (S4["u1"][i] + S4["d1"][i]))
    
    
for i in tqdm(range(len(S3["u1"]))):
    if(i==0):
        continue
    if (S3["u1"][i] == 0 or S3["u1"][i] == -1 or T3["u1"][i] == 0 or T3["d1"][i] == -1 or i>=len(S3["u1"])):
        continue
    A3.append((T3["u1"][i] + T3["d1"][i]) / (S3["u1"][i] + S3["d1"][i]))









    
G1=[A6,A7,A1,A5,A0,A2,A4,A3] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsp=N1
# Out:
# 100%|██████████| 1049/1049 [00:00<00:00, 14490.98it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 10029.23it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 11878.22it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 7461.35it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 6344.96it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 4353.33it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 4393.61it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 10508.20it/s]

# %%
new_paramsp
# Out:
#           x_na      y_na    g_unav     g_cav    g_kvhh     g_nak    g_lena  \
# 0     1.210907  0.992230  0.948980  0.995419  0.956448  1.177400  0.944126
# 1     1.360681  0.940096  1.012954  0.954452  0.938300  0.969447  0.951439
# 2     1.623870  0.962224  1.102786  1.684709  0.718405  0.480081  0.588045
# 3     1.146088  0.845014  1.019200  1.022833  0.877412  0.962923  0.958498
# 4     1.370377  0.252662  0.239474  0.666750  1.009654  0.655754  0.851580
# ...        ...       ...       ...       ...       ...       ...       ...
# 1001       NaN       NaN       NaN       NaN       NaN  0.928939       NaN
# 1002       NaN       NaN       NaN       NaN       NaN  0.939356       NaN
# 1003       NaN       NaN       NaN       NaN       NaN  0.984867       NaN
# 1004       NaN       NaN       NaN       NaN       NaN  0.949301       NaN
# 1005       NaN       NaN       NaN       NaN       NaN  0.963472       NaN
#
#          g_lek
# 0     0.995982
# 1     1.012476
# 2     1.032125
# 3     1.014311
# 4     0.709063
# ...        ...
# 1001       NaN
# 1002       NaN
# 1003       NaN
# 1004       NaN
# 1005       NaN
#
# [1006 rows x 8 columns]

# %%
fig=plt.figure(figsize=(10,10))
ax=sns.stripplot(data=new_paramsp)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            data=new_paramsp,
            showfliers=False,
            showbox=False,
            showcaps=False,
            )
# 描画
# Out:
# <AxesSubplot:>

# %%
def normalize_rgb(rgb):
    return tuple(component / 255 for component in rgb)
G1=[np.log10(A6),np.log10(A1),np.log10(A3),np.log10(A2),np.log10(A4),np.log10(A7),np.log10(A5),np.log10(A0)] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsn=N1


new_paramsn = new_paramsn.select_dtypes(include=[np.number])
CC=[(202,28,29), (213,94,22), (26,47,111), (128,27,115), (245,233,40)]
COLOR1=[CC[0],CC[0],CC[0],CC[1],CC[2],CC[2],CC[3],CC[3]]

fig, ax = plt.subplots(figsize=(16, 9))
count=0


for index, column in enumerate(new_paramsn.columns):
    y = new_paramsn[column]
    x = np.random.normal(loc=index, scale=0.04, size=len(y))
    ax.scatter(x, y, c=normalize_rgb(COLOR1[count]), zorder=5)
    count=count+1
    

for index, column in enumerate(new_paramsn.columns):
    mean_value = new_paramsn[column].mean()
    ax.axhline(y=mean_value, color='k', linestyle='-', linewidth=0.5, xmin=index/len(new_paramsn.columns), xmax=(index+1)/len(new_paramsn.columns))


ax.set_xticks(np.arange(len(new_paramsn.columns)))
ax.set_xticklabels(new_paramsn.columns, rotation=90)

ax.set_yticks([-1.5, 0, 1.5])

plt.savefig("UD.pdf")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
A0=[]
A1=[]
A2=[]
A3=[]
A4=[]
A5=[]
A6=[]
A7=[]


BBB=[ 'x_na', 'g_unav', 'g_lek', 'g_nak', 'g_lena','y_na','g_cav', 'g_kvhh']

S0 = pd.read_csv("OD0.csv")
T0 = pd.read_csv("OD10.csv")
S1 = pd.read_csv("OD1.csv")
T1 = pd.read_csv("OD11.csv")
S2 = pd.read_csv("OD2.csv")
T2 = pd.read_csv("OD12.csv")
S3 = pd.read_csv("OD3.csv")
T3 = pd.read_csv("OD13.csv")
S4 = pd.read_csv("OD4.csv")
T4 = pd.read_csv("OD14.csv")
S5 = pd.read_csv("OD5.csv")
T5 = pd.read_csv("OD15.csv")
S6 = pd.read_csv("OD6.csv")
T6 = pd.read_csv("OD16.csv")
S7 = pd.read_csv("OD7.csv")
T7 = pd.read_csv("OD17.csv")


for i in tqdm(range(len(S6["u1"]))):
    if(i==0):
        continue
    if (S6["u1"][i] == 0 or S6["u1"][i] == -1 or T6["u1"][i] == 0 or T6["d1"][i] == -1):
        continue
    A6.append((T6["u1"][i]) / (S6["u1"][i]))




for i in tqdm(range(len(S1["u1"]))):
    if(i==0):
        continue
    if (S1["u1"][i] == 0 or S1["u1"][i] == -1 or T1["u1"][i] == 0 or T1["d1"][i] == -1 or i>=len(S1["u1"])):
        continue
    A1.append((T1["u1"][i]) / (S1["u1"][i]))

for i in tqdm(range(len(S3["u1"]))):
    if(i==0):
        continue
    if (S3["u1"][i] == 0 or S3["u1"][i] == -1 or T3["u1"][i] == 0 or T3["d1"][i] == -1 or i>=len(S3["u1"])):
        continue
    A3.append((T3["u1"][i]) / (S3["u1"][i]))

for i in tqdm(range(len(S2["u1"]))):
    if(i==0):
        continue
    if (S2["u1"][i] == 0 or S2["u1"][i] == -1 or T2["u1"][i] == 0 or T2["d1"][i] == -1 or i>=len(S2["u1"])):
        continue
    A2.append((T2["u1"][i]) / (S2["u1"][i] ))

for i in tqdm(range(len(S4["u1"]))):
    if(i==0):
        continue
    if (S4["u1"][i] == 0 or S4["u1"][i] == -1 or T4["u1"][i] == 0 or T4["d1"][i] == -1 or i>=len(S4["u1"])):
        continue
    A4.append((T4["u1"][i] ) / (S4["u1"][i] ))


for i in tqdm(range(len(S7["u1"]))):
    if(i==0):
        continue
    if (S7["u1"][i] == 0 or S7["u1"][i] == -1 or T7["u1"][i] == 0 or T7["d1"][i] == -1 or i>=len(S7["u1"])):
        continue
    A7.append((T7["u1"][i] ) / (S7["u1"][i] ))


for i in tqdm(range(len(S5["u1"]))):
    if(i==0):
        continue
    if (S5["u1"][i] == 0 or S5["u1"][i] == -1 or T5["u1"][i] == 0 or T5["d1"][i] == -1 or i>=len(S5["u1"])):
        continue
    A5.append((T5["u1"][i]) / (S5["u1"][i] ))


for i in tqdm(range(len(S0["u1"]))):
    if(i==0):
        continue
    if (S0["u1"][i] == 0 or S0["u1"][i] == -1 or T0["u1"][i] == 0 or T0["d1"][i] == -1 or i>=len(S0["u1"])):
        continue
    A0.append((T0["u1"][i] ) / (S0["u1"][i]))



    
G1=[A6,A1,A3,A2,A4,A7,A5,A0] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsp=N1

fig=plt.figure(figsize=(10,10))
ax=sns.stripplot(data=new_paramsp)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            data=new_paramsp,
            showfliers=False,
            showbox=False,
            showcaps=False,
            )
# 描画
# Out:
# 100%|██████████| 1049/1049 [00:00<00:00, 42133.42it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 7172.74it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 9574.93it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 10404.80it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 13400.45it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 9637.09it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 15062.99it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 13155.92it/s]
# <AxesSubplot:>

# %%
def normalize_rgb(rgb):
    return tuple(component / 255 for component in rgb)
G1=[np.log10(A6),np.log10(A1),np.log10(A3),np.log10(A2),np.log10(A4),np.log10(A7),np.log10(A5),np.log10(A0)] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsn=N1


new_paramsn = new_paramsn.select_dtypes(include=[np.number])
CC=[(202,28,29), (213,94,22), (26,47,111), (128,27,115), (245,233,40)]
COLOR1=[CC[0],CC[0],CC[0],CC[1],CC[2],CC[2],CC[3],CC[3]]

fig, ax = plt.subplots(figsize=(16, 9))
count=0

for index, column in enumerate(new_paramsn.columns):
    y = new_paramsn[column]
    x = np.random.normal(loc=index, scale=0.04, size=len(y))
    ax.scatter(x, y, c=normalize_rgb(COLOR1[count]), zorder=5)
    count=count+1
    

for index, column in enumerate(new_paramsn.columns):
    mean_value = new_paramsn[column].mean()
    ax.axhline(y=mean_value, color='k', linestyle='-', linewidth=0.5, xmin=index/len(new_paramsn.columns), xmax=(index+1)/len(new_paramsn.columns))

ax.set_xticks(np.arange(len(new_paramsn.columns)))
ax.set_xticklabels(new_paramsn.columns, rotation=90)

ax.set_yticks([-1.5, 0, 1.5])

plt.savefig("U.pdf")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
A0=[]
A1=[]
A2=[]
A3=[]
A4=[]
A5=[]
A6=[]
A7=[]


BBB=[ 'x_na', 'g_unav', 'g_lek', 'g_nak', 'g_lena','y_na','g_cav', 'g_kvhh']

S0 = pd.read_csv("OD0.csv")
T0 = pd.read_csv("OD10.csv")
S1 = pd.read_csv("OD1.csv")
T1 = pd.read_csv("OD11.csv")
S2 = pd.read_csv("OD2.csv")
T2 = pd.read_csv("OD12.csv")
S3 = pd.read_csv("OD3.csv")
T3 = pd.read_csv("OD13.csv")
S4 = pd.read_csv("OD4.csv")
T4 = pd.read_csv("OD14.csv")
S5 = pd.read_csv("OD5.csv")
T5 = pd.read_csv("OD15.csv")
S6 = pd.read_csv("OD6.csv")
T6 = pd.read_csv("OD16.csv")
S7 = pd.read_csv("OD7.csv")
T7 = pd.read_csv("OD17.csv")


for i in tqdm(range(len(S6["u1"]))):
    if(i==0):
        continue
    if (S6["u1"][i] == 0 or S6["u1"][i] == -1 or T6["u1"][i] == 0 or T6["d1"][i] == -1):
        continue
    A6.append((T6["d1"][i]) / (S6["d1"][i]))




for i in tqdm(range(len(S1["u1"]))):
    if(i==0):
        continue
    if (S1["u1"][i] == 0 or S1["u1"][i] == -1 or T1["u1"][i] == 0 or T1["d1"][i] == -1 or i>=len(S1["u1"])):
        continue
    A1.append((T1["d1"][i]) / (S1["d1"][i]))

for i in tqdm(range(len(S3["u1"]))):
    if(i==0):
        continue
    if (S3["u1"][i] == 0 or S3["u1"][i] == -1 or T3["u1"][i] == 0 or T3["d1"][i] == -1 or i>=len(S3["u1"])):
        continue
    A3.append(( T3["d1"][i]) / (S3["d1"][i]))

for i in tqdm(range(len(S2["u1"]))):
    if(i==0):
        continue
    if (S2["u1"][i] == 0 or S2["u1"][i] == -1 or T2["u1"][i] == 0 or T2["d1"][i] == -1 or i>=len(S2["u1"])):
        continue
    A2.append((T2["d1"][i]) / ( S2["d1"][i]))

for i in tqdm(range(len(S4["u1"]))):
    if(i==0):
        continue
    if (S4["u1"][i] == 0 or S4["u1"][i] == -1 or T4["u1"][i] == 0 or T4["d1"][i] == -1 or i>=len(S4["u1"])):
        continue
    A4.append((T4["d1"][i]) / (S4["d1"][i]))


for i in tqdm(range(len(S7["u1"]))):
    if(i==0):
        continue
    if (S7["u1"][i] == 0 or S7["u1"][i] == -1 or T7["u1"][i] == 0 or T7["d1"][i] == -1 or i>=len(S7["u1"])):
        continue
    A7.append(( T7["d1"][i]) / (S7["d1"][i]))


for i in tqdm(range(len(S5["u1"]))):
    if(i==0):
        continue
    if (S5["u1"][i] == 0 or S5["u1"][i] == -1 or T5["u1"][i] == 0 or T5["d1"][i] == -1 or i>=len(S5["u1"])):
        continue
    A5.append((T5["d1"][i]) / (S5["d1"][i]))


for i in tqdm(range(len(S0["u1"]))):
    if(i==0):
        continue
    if (S0["u1"][i] == 0 or S0["u1"][i] == -1 or T0["u1"][i] == 0 or T0["d1"][i] == -1 or i>=len(S0["u1"])):
        continue
    A0.append((T0["d1"][i]) / ( S0["d1"][i]))



    
G1=[A6,A1,A3,A2,A4,A7,A5,A0] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsp=N1

fig=plt.figure(figsize=(10,10))
ax=sns.stripplot(data=new_paramsp)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            data=new_paramsp,
            showfliers=False,
            showbox=False,
            showcaps=False,
            )
# 描画
# Out:
# 100%|██████████| 1049/1049 [00:00<00:00, 31516.69it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 8908.55it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 12968.05it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 16620.17it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 8782.12it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 14325.33it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 11204.01it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 14369.07it/s]
# <AxesSubplot:>

# %%
def normalize_rgb(rgb):
    return tuple(component / 255 for component in rgb)
G1=[np.log10(A6),np.log10(A1),np.log10(A3),np.log10(A2),np.log10(A4),np.log10(A7),np.log10(A5),np.log10(A0)] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsn=N1


new_paramsn = new_paramsn.select_dtypes(include=[np.number])
CC=[(202,28,29), (213,94,22), (26,47,111), (128,27,115), (245,233,40)]
COLOR1=[CC[0],CC[0],CC[0],CC[1],CC[2],CC[2],CC[3],CC[3]]

fig, ax = plt.subplots(figsize=(16, 9))
count=0

for index, column in enumerate(new_paramsn.columns):
    y = new_paramsn[column]
    x = np.random.normal(loc=index, scale=0.04, size=len(y))
    ax.scatter(x, y, c=normalize_rgb(COLOR1[count]), zorder=5)
    count=count+1
    

for index, column in enumerate(new_paramsn.columns):
    mean_value = new_paramsn[column].mean()
    ax.axhline(y=mean_value, color='k', linestyle='-', linewidth=0.5, xmin=index/len(new_paramsn.columns), xmax=(index+1)/len(new_paramsn.columns))

ax.set_xticks(np.arange(len(new_paramsn.columns)))
ax.set_xticklabels(new_paramsn.columns, rotation=90)

ax.set_yticks([-1.5, 0, 1.5])

plt.savefig("D.pdf")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
A0=[]
A1=[]
A2=[]
A3=[]
A4=[]
A5=[]
A6=[]
A7=[]


BBB=[ 'x_na', 'y_na', 'g_unav', 'g_cav', 'g_kvhh','g_nak','g_lena', 'g_lek']

S0 = pd.read_csv("OD0.csv")
T0 = pd.read_csv("OD10.csv")
S1 = pd.read_csv("OD1.csv")
T1 = pd.read_csv("OD11.csv")
S2 = pd.read_csv("OD2.csv")
T2 = pd.read_csv("OD12.csv")
S3 = pd.read_csv("OD3.csv")
T3 = pd.read_csv("OD13.csv")
S4 = pd.read_csv("OD4.csv")
T4 = pd.read_csv("OD14.csv")
S5 = pd.read_csv("OD5.csv")
T5 = pd.read_csv("OD15.csv")
S6 = pd.read_csv("OD6.csv")
T6 = pd.read_csv("OD16.csv")
S7 = pd.read_csv("OD7.csv")
T7 = pd.read_csv("OD17.csv")


for i in tqdm(range(len(S6["u1"]))):
    if(i==0):
        continue
    if (S6["u1"][i] == 0 or S6["u1"][i] == -1 or T6["u1"][i] == 0 or T6["d1"][i] == -1):
        continue
    A6.append((T6["max"][i]-T6["min"][i]) / (S6["max"][i]-S6["min"][i]))
    if((T6["max"][i]-T6["min"][i]) / (S6["max"][i]-S6["min"][i])>200):
        print(i)
    
for i in tqdm(range(len(S7["u1"]))):
    if(i==0):
        continue
    if (S7["u1"][i] == 0 or S7["u1"][i] == -1 or T7["u1"][i] == 0 or T7["d1"][i] == -1):
        continue
    A7.append((T7["max"][i]-T7["min"][i]) / (S7["max"][i]-S7["min"][i]))   


for i in tqdm(range(len(S1["u1"]))):
    if(i==0):
        continue
    if (S1["u1"][i] == 0 or S1["u1"][i] == -1 or T1["u1"][i] == 0 or T1["d1"][i] == -1):
        continue
    A1.append((T1["max"][i]-T1["min"][i]) / (S1["max"][i]-S1["min"][i]))

for i in tqdm(range(len(S5["u1"]))):
    if(i==0):
        continue
    if (S5["u1"][i] == 0 or S5["u1"][i] == -1 or T5["u1"][i] == 0 or T5["d1"][i] == -1):
        continue
        
    A5.append((T5["max"][i]-T5["min"][i]) / (S5["max"][i]-S5["min"][i]))
    
    
for i in tqdm(range(len(S0["u1"]))):
    if(i==0):
        continue
    if (S0["u1"][i] == 0 or S0["u1"][i] == -1 or T0["u1"][i] == 0 or T0["d1"][i] == -1 or i>=len(S0["u1"])):
        continue
    A0.append((T0["max"][i]-T0["min"][i]) / (S0["max"][i]-S0["min"][i]))
    
for i in tqdm(range(len(S2["u1"]))):
    if(i==0):
        continue
    if (S2["u1"][i] == 0 or S2["u1"][i] == -1 or T2["u1"][i] == 0 or T2["d1"][i] == -1):
        continue
    A2.append((T2["max"][i]-T2["min"][i]) / (S2["max"][i]-S2["min"][i]))
    

    
for i in tqdm(range(len(S4["u1"]))):
    if(i==0):
        continue
    if (S4["u1"][i] == 0 or S4["u1"][i] == -1 or T4["u1"][i] == 0 or T4["d1"][i] == -1):
        continue
    A4.append((T4["max"][i]-T4["min"][i]) / (S4["max"][i]-S4["min"][i]))
    
    
for i in tqdm(range(len(S3["u1"]))):
    if(i==0):
        continue
    if (S3["u1"][i] == 0 or S3["u1"][i] == -1 or T3["u1"][i] == 0 or T3["d1"][i] == -1):
        continue
    A3.append((T3["max"][i]-T3["min"][i]) / (S3["max"][i]-S3["min"][i]))



G1=[A6,A7,A1,A5,A0,A2,A4,A3] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsp=N1

fig=plt.figure(figsize=(10,10))
ax=sns.stripplot(data=new_paramsp)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            data=new_paramsp,
            showfliers=False,
            showbox=False,
            showcaps=False,
            )
# Out:
# 100%|██████████| 1049/1049 [00:00<00:00, 19240.43it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 10018.34it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 12091.52it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 10854.04it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 11952.51it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 14658.66it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 12165.03it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 10147.83it/s]
# <AxesSubplot:>

# %%
def normalize_rgb(rgb):
    return tuple(component / 255 for component in rgb)
G1=[np.log10(A6),np.log10(A1),np.log10(A3),np.log10(A2),np.log10(A4),np.log10(A7),np.log10(A5),np.log10(A0)] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsn=N1


new_paramsn = new_paramsn.select_dtypes(include=[np.number])
CC=[(202,28,29), (213,94,22), (26,47,111), (128,27,115), (245,233,40)]
COLOR1=[CC[0],CC[0],CC[0],CC[1],CC[2],CC[2],CC[3],CC[3]]

fig, ax = plt.subplots(figsize=(16, 9))
count=0

for index, column in enumerate(new_paramsn.columns):
    y = new_paramsn[column]
    x = np.random.normal(loc=index, scale=0.04, size=len(y))
    ax.scatter(x, y, c=normalize_rgb(COLOR1[count]), zorder=5)
    count=count+1
    

for index, column in enumerate(new_paramsn.columns):
    mean_value = new_paramsn[column].mean()
    ax.axhline(y=mean_value, color='k', linestyle='-', linewidth=0.5, xmin=index/len(new_paramsn.columns), xmax=(index+1)/len(new_paramsn.columns))

ax.set_xticks(np.arange(len(new_paramsn.columns)))
ax.set_xticklabels(new_paramsn.columns, rotation=90)


ax.set_yticks([-1.5, 0, 1.5])

plt.savefig("O.pdf")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
#659, no

# %%
A0=[]
A1=[]
A2=[]
A3=[]
A4=[]
A5=[]
A6=[]
A7=[]


BBB=[ 'x_na', 'y_na', 'g_unav', 'g_cav', 'g_kvhh','g_nak','g_lena', 'g_lek']

S0 = pd.read_csv("OD0.csv")
T0 = pd.read_csv("OD10.csv")
S1 = pd.read_csv("OD1.csv")
T1 = pd.read_csv("OD11.csv")
S2 = pd.read_csv("OD2.csv")
T2 = pd.read_csv("OD12.csv")
S3 = pd.read_csv("OD3.csv")
T3 = pd.read_csv("OD13.csv")
S4 = pd.read_csv("OD4.csv")
T4 = pd.read_csv("OD14.csv")
S5 = pd.read_csv("OD5.csv")
T5 = pd.read_csv("OD15.csv")
S6 = pd.read_csv("OD6.csv")
T6 = pd.read_csv("OD16.csv")
S7 = pd.read_csv("OD7.csv")
T7 = pd.read_csv("OD17.csv")


for i in tqdm(range(len(S6["u1"]))):
    if(i==0):
        continue
    if (S6["u1"][i] == 0 or S6["u1"][i] == -1 or T6["u1"][i] == 0 or T6["d1"][i] == -1):
        continue
    A6.append((T6["mean"][i]) / (S6["mean"][i]))

for i in tqdm(range(len(S7["u1"]))):
    if(i==0):
        continue
    if (S7["u1"][i] == 0 or S7["u1"][i] == -1 or T7["u1"][i] == 0 or T7["d1"][i] == -1 or i>=len(S7["u1"])):
        continue
    A7.append(( T7["mean"][i]) / (S7["mean"][i]))
    
    
for i in tqdm(range(len(S1["u1"]))):
    if(i==0):
        continue
    if (S1["u1"][i] == 0 or S1["u1"][i] == -1 or T1["u1"][i] == 0 or T1["d1"][i] == -1 or i>=len(S1["u1"])):
        continue
    A1.append((T1["mean"][i]) / (S1["mean"][i]))

for i in tqdm(range(len(S5["u1"]))):
    if(i==0):
        continue
    if (S5["u1"][i] == 0 or S5["u1"][i] == -1 or T5["u1"][i] == 0 or T5["d1"][i] == -1 or i>=len(S5["u1"])):
        continue
    A5.append((T5["mean"][i]) / (S5["mean"][i]))
    
for i in tqdm(range(len(S0["u1"]))):
    if(i==0):
        continue
    if (S0["u1"][i] == 0 or S0["u1"][i] == -1 or T0["u1"][i] == 0 or T0["d1"][i] == -1 or i>=len(S0["u1"])):
        continue
    A0.append((T0["mean"][i]) / ( S0["mean"][i]))
    

for i in tqdm(range(len(S2["u1"]))):
    if(i==0):
        continue
    if (S2["u1"][i] == 0 or S2["u1"][i] == -1 or T2["u1"][i] == 0 or T2["d1"][i] == -1 or i>=len(S2["u1"])):
        continue
    A2.append((T2["mean"][i]) / ( S2["mean"][i]))

for i in tqdm(range(len(S4["u1"]))):
    if(i==0):
        continue
    if (S4["u1"][i] == 0 or S4["u1"][i] == -1 or T4["u1"][i] == 0 or T4["d1"][i] == -1 or i>=len(S4["u1"])):
        continue
    A4.append((T4["mean"][i]) / (S4["mean"][i]))
    
    
for i in tqdm(range(len(S3["u1"]))):
    if(i==0):
        continue
    if (S3["u1"][i] == 0 or S3["u1"][i] == -1 or T3["u1"][i] == 0 or T3["d1"][i] == -1 or i>=len(S3["u1"])):
        continue
    A3.append(( T3["mean"][i]) / (S3["mean"][i]))






    
G1=[A6,A6,A1,A5,A0,A2,A4,A3] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsp=N1

fig=plt.figure(figsize=(10,10))
ax=sns.stripplot(data=new_paramsp)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            data=new_paramsp,
            showfliers=False,
            showbox=False,
            showcaps=False,
            )
# 描画
# Out:
# 100%|██████████| 1049/1049 [00:00<00:00, 23672.54it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 17081.06it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 10753.78it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 5028.74it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 18283.24it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 14523.08it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 20765.74it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 14970.48it/s]
# <AxesSubplot:>

# %%
def normalize_rgb(rgb):
    return tuple(component / 255 for component in rgb)
G1=[np.log10(A6),np.log10(A1),np.log10(A3),np.log10(A2),np.log10(A4),np.log10(A7),np.log10(A5),np.log10(A0)] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsn=N1


new_paramsn = new_paramsn.select_dtypes(include=[np.number])
CC=[(202,28,29), (213,94,22), (26,47,111), (128,27,115), (245,233,40)]
COLOR1=[CC[0],CC[0],CC[0],CC[1],CC[2],CC[2],CC[3],CC[3]]

fig, ax = plt.subplots(figsize=(16, 9))
count=0

for index, column in enumerate(new_paramsn.columns):
    y = new_paramsn[column]
    x = np.random.normal(loc=index, scale=0.04, size=len(y))
    ax.scatter(x, y, c=normalize_rgb(COLOR1[count]), zorder=5)
    count=count+1
    

for index, column in enumerate(new_paramsn.columns):
    mean_value = new_paramsn[column].mean()
    ax.axhline(y=mean_value, color='k', linestyle='-', linewidth=0.5, xmin=index/len(new_paramsn.columns), xmax=(index+1)/len(new_paramsn.columns))

ax.set_xticks(np.arange(len(new_paramsn.columns)))
ax.set_xticklabels(new_paramsn.columns, rotation=90)

ax.set_yticks([-1.5, 0, 1.5])

plt.savefig("I.pdf")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
