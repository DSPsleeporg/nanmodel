# %%
import os
import sys
import requests
from datetime import datetime 
from multiprocessing import Pool
import numpy as  np
import pandas as pd
from pathlib import Path
import pickle
from tqdm import tqdm
from time import time
from typing import Dict, List, Optional
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
plt.rcParams['font.family'] = 'Arial'

# %%
A0=[]
A1=[]
A2=[]
A3=[]
A4=[]
A5=[]
A6=[]
A7=[]
A8=[]

BBB=[ 'x_na','y_na',  'g_unav', 'g_cav', 'g_lena','g_lek', 'g_kvhh', 'g_kna','t_na']


S0 = pd.read_csv("OD0.csv")
T0 = pd.read_csv("OD10.csv")
S1 = pd.read_csv("OD1.csv")
T1 = pd.read_csv("OD11.csv")
S2 = pd.read_csv("OD2.csv")
T2 = pd.read_csv("OD12.csv")
S3 = pd.read_csv("OD3.csv")
T3 = pd.read_csv("OD13.csv")
S4 = pd.read_csv("OD4.csv")
T4 = pd.read_csv("OD14.csv")
S5 = pd.read_csv("OD5.csv")
T5 = pd.read_csv("OD15.csv")
S6 = pd.read_csv("OD6.csv")
T6 = pd.read_csv("OD16.csv")
S7 = pd.read_csv("OD7.csv")
T7 = pd.read_csv("OD17.csv")
S8 = pd.read_csv("OD8.csv")
T8 = pd.read_csv("OD18.csv")

for i in tqdm(range(len(S6["u1"]))):
    if(i==0):
        continue
    if (S6["u1"][i] == 0 or S6["u1"][i] == -1 or T6["u1"][i] == 0 or T6["d1"][i] == -1):
        continue
    A6.append((T6["u1"][i] + T6["d1"][i]) / (S6["u1"][i] + S6["d1"][i]))

for i in tqdm(range(len(S7["u1"]))):
    if(i==0):
        continue
    if (S7["u1"][i] == 0 or S7["u1"][i] == -1 or T7["u1"][i] == 0 or T7["d1"][i] == -1 or i>=len(S7["u1"])):
        continue
    A7.append((T7["u1"][i] + T7["d1"][i]) / (S7["u1"][i] + S7["d1"][i]))

    
for i in tqdm(range(len(S1["u1"]))):
    if(i==0):
        continue
    if (S1["u1"][i] == 0 or S1["u1"][i] == -1 or T1["u1"][i] == 0 or T1["d1"][i] == -1 or i>=len(S1["u1"])):
        continue
    A1.append((T1["u1"][i] + T1["d1"][i]) / (S1["u1"][i] + S1["d1"][i]))
    

for i in tqdm(range(len(S5["u1"]))):
    if(i==0):
        continue
    if (S5["u1"][i] == 0 or S5["u1"][i] == -1 or T5["u1"][i] == 0 or T5["d1"][i] == -1 or i>=len(S5["u1"])):
        continue
    A5.append((T5["u1"][i] + T5["d1"][i]) / (S5["u1"][i] + S5["d1"][i]))
    
for i in tqdm(range(len(S0["u1"]))):
    if(i==0):
        continue
    if (S0["u1"][i] == 0 or S0["u1"][i] == -1 or T0["u1"][i] == 0 or T0["d1"][i] == -1 or i>=len(S0["u1"])):
        continue
    A0.append((T0["u1"][i] + T0["d1"][i]) / (S0["u1"][i] + S0["d1"][i]))
    

for i in tqdm(range(len(S2["u1"]))):
    if(i==0):
        continue
    if (S2["u1"][i] == 0 or S2["u1"][i] == -1 or T2["u1"][i] == 0 or T2["d1"][i] == -1 or i>=len(S2["u1"])):
        continue
    A2.append((T2["u1"][i] + T2["d1"][i]) / (S2["u1"][i] + S2["d1"][i]))
    

for i in tqdm(range(len(S4["u1"]))):
    if(i==0):
        continue
    if (S4["u1"][i] == 0 or S4["u1"][i] == -1 or T4["u1"][i] == 0 or T4["d1"][i] == -1 or i>=len(S4["u1"])):
        continue
    A4.append((T4["u1"][i] + T4["d1"][i]) / (S4["u1"][i] + S4["d1"][i]))
    

for i in tqdm(range(len(S3["u1"]))):
    if(i==0):
        continue
    if (S3["u1"][i] == 0 or S3["u1"][i] == -1 or T3["u1"][i] == 0 or T3["d1"][i] == -1 or i>=len(S3["u1"])):
        continue
    A3.append((T3["u1"][i] + T3["d1"][i]) / (S3["u1"][i] + S3["d1"][i]))

    
    
for i in tqdm(range(len(S8["u1"]))):
    if(i==0):
        continue
    if (S8["u1"][i] == 0 or S8["u1"][i] == -1 or T8["u1"][i] == 0 or T8["d1"][i] == -1 or i>=len(S8["u1"])):
        continue
    A8.append((T8["u1"][i] + T8["d1"][i]) / (S8["u1"][i] + S8["d1"][i]))

    
    
G1=[A6,A7,A1,A5,A0,A2,A4,A3,A8] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsp=N1
# Out:
# 100%|██████████| 1132/1132 [00:00<00:00, 34940.19it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 7526.79it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 9258.34it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 10085.61it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 13593.23it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 10095.88it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 13359.76it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 14266.77it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 13640.05it/s]

# %%
fig=plt.figure(figsize=(10,10))
ax=sns.stripplot(data=new_paramsp)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            data=new_paramsp,
            showfliers=False,
            showbox=False,
            showcaps=False,
            )
# Out:
# <AxesSubplot:>

# %%
def normalize_rgb(rgb):
    return tuple(component / 255 for component in rgb)
G1=[np.log10(A6),np.log10(A7),np.log10(A1),np.log10(A5),np.log10(A0),np.log10(A2),np.log10(A4),np.log10(A3),np.log10(A8)] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsn=N1

new_paramsn = new_paramsn.select_dtypes(include=[np.number])
CC=[(202,28,29), (213,94,22), (26,47,111), (128,27,115), (245,233,40)]
COLOR1=[CC[0],CC[0],CC[0],CC[1],CC[2],CC[2],CC[3],CC[3],CC[4]]

fig, ax = plt.subplots(figsize=(16, 9))
count=0

for index, column in enumerate(new_paramsn.columns):
    y = new_paramsn[column]
    x = np.random.normal(loc=index, scale=0.04, size=len(y))
    ax.scatter(x, y, c=normalize_rgb(COLOR1[count]), zorder=5)
    count=count+1
    

for index, column in enumerate(new_paramsn.columns):
    mean_value = new_paramsn[column].mean()
    ax.axhline(y=mean_value, color='k', linestyle='-', linewidth=0.5, xmin=index/len(new_paramsn.columns), xmax=(index+1)/len(new_paramsn.columns))

ax.set_xticks(np.arange(len(new_paramsn.columns)))
ax.set_xticklabels(new_paramsn.columns, rotation=90)

ax.set_yticks([-1.5, 0, 1.5])

plt.savefig("UD.pdf")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
A0=[]
A1=[]
A2=[]
A3=[]
A4=[]
A5=[]
A6=[]
A7=[]
A8=[]

BBB=[ 'x_na','y_na',  'g_unav', 'g_cav', 'g_lena','g_lek', 'g_kvhh', 'g_kna','t_na']

S0 = pd.read_csv("OD0.csv")
T0 = pd.read_csv("OD10.csv")
S1 = pd.read_csv("OD1.csv")
T1 = pd.read_csv("OD11.csv")
S2 = pd.read_csv("OD2.csv")
T2 = pd.read_csv("OD12.csv")
S3 = pd.read_csv("OD3.csv")
T3 = pd.read_csv("OD13.csv")
S4 = pd.read_csv("OD4.csv")
T4 = pd.read_csv("OD14.csv")
S5 = pd.read_csv("OD5.csv")
T5 = pd.read_csv("OD15.csv")
S6 = pd.read_csv("OD6.csv")
T6 = pd.read_csv("OD16.csv")
S7 = pd.read_csv("OD7.csv")
T7 = pd.read_csv("OD17.csv")
S8 = pd.read_csv("OD8.csv")
T8 = pd.read_csv("OD18.csv")

for i in tqdm(range(len(S6["u1"]))):
    if(i==0):
        continue
    if (S6["u1"][i] == 0 or S6["u1"][i] == -1 or T6["u1"][i] == 0 or T6["d1"][i] == -1):
        continue
    A6.append((T6["u1"][i]) / (S6["u1"][i]))

for i in tqdm(range(len(S7["u1"]))):
    if(i==0):
        continue
    if (S7["u1"][i] == 0 or S7["u1"][i] == -1 or T7["u1"][i] == 0 or T7["d1"][i] == -1 or i>=len(S7["u1"])):
        continue
    A7.append((T7["u1"][i] ) / (S7["u1"][i] ))
    
for i in tqdm(range(len(S1["u1"]))):
    if(i==0):
        continue
    if (S1["u1"][i] == 0 or S1["u1"][i] == -1 or T1["u1"][i] == 0 or T1["d1"][i] == -1 or i>=len(S1["u1"])):
        continue
    A1.append((T1["u1"][i]) / (S1["u1"][i]))
    
for i in tqdm(range(len(S5["u1"]))):
    if(i==0):
        continue
    if (S5["u1"][i] == 0 or S5["u1"][i] == -1 or T5["u1"][i] == 0 or T5["d1"][i] == -1 or i>=len(S5["u1"])):
        continue
    A5.append((T5["u1"][i]) / (S5["u1"][i] ))
    


for i in tqdm(range(len(S0["u1"]))):
    if(i==0):
        continue
    if (S0["u1"][i] == 0 or S0["u1"][i] == -1 or T0["u1"][i] == 0 or T0["d1"][i] == -1 or i>=len(S0["u1"])):
        continue
    A0.append((T0["u1"][i] ) / (S0["u1"][i]))
    
    
for i in tqdm(range(len(S2["u1"]))):
    if(i==0):
        continue
    if (S2["u1"][i] == 0 or S2["u1"][i] == -1 or T2["u1"][i] == 0 or T2["d1"][i] == -1 or i>=len(S2["u1"])):
        continue
    A2.append((T2["u1"][i]) / (S2["u1"][i] ))
    

for i in tqdm(range(len(S4["u1"]))):
    if(i==0):
        continue
    if (S4["u1"][i] == 0 or S4["u1"][i] == -1 or T4["u1"][i] == 0 or T4["d1"][i] == -1 or i>=len(S4["u1"])):
        continue
    A4.append((T4["u1"][i] ) / (S4["u1"][i] ))
    
for i in tqdm(range(len(S3["u1"]))):
    if(i==0):
        continue
    if (S3["u1"][i] == 0 or S3["u1"][i] == -1 or T3["u1"][i] == 0 or T3["d1"][i] == -1 or i>=len(S3["u1"])):
        continue
    A3.append((T3["u1"][i]) / (S3["u1"][i]))
    
    
for i in tqdm(range(len(S8["u1"]))):
    if(i==0):
        continue
    if (S8["u1"][i] == 0 or S8["u1"][i] == -1 or T8["u1"][i] == 0 or T8["d1"][i] == -1 or i>=len(S8["u1"])):
        continue
    A8.append((T8["u1"][i]) / (S8["u1"][i]))





    
G1=[A6,A7,A1,A5,A0,A2,A4,A3,A8] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsp=N1

fig=plt.figure(figsize=(10,10))
ax=sns.stripplot(data=new_paramsp)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            data=new_paramsp,
            showfliers=False,
            showbox=False,
            showcaps=False,
            )
# 描画
# Out:
# 100%|██████████| 1132/1132 [00:00<00:00, 42885.61it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 14591.35it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 16355.33it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 17383.04it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 16653.64it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 12325.65it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 22305.83it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 17430.46it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 15085.70it/s]
# <AxesSubplot:>

# %%
def normalize_rgb(rgb):
    return tuple(component / 255 for component in rgb)
G1=[np.log10(A6),np.log10(A7),np.log10(A1),np.log10(A5),np.log10(A0),np.log10(A2),np.log10(A4),np.log10(A3),np.log10(A8)] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsn=N1




new_paramsn = new_paramsn.select_dtypes(include=[np.number])
CC=[(202,28,29), (213,94,22), (26,47,111), (128,27,115), (245,233,40)]
COLOR1=[CC[0],CC[0],CC[0],CC[1],CC[2],CC[2],CC[3],CC[3],CC[4]]

fig, ax = plt.subplots(figsize=(16, 9))
count=0

for index, column in enumerate(new_paramsn.columns):
    y = new_paramsn[column]
    x = np.random.normal(loc=index, scale=0.04, size=len(y))
    ax.scatter(x, y, c=normalize_rgb(COLOR1[count]), zorder=5)
    count=count+1
    
for index, column in enumerate(new_paramsn.columns):
    mean_value = new_paramsn[column].mean()
    ax.axhline(y=mean_value, color='k', linestyle='-', linewidth=0.5, xmin=index/len(new_paramsn.columns), xmax=(index+1)/len(new_paramsn.columns))

ax.set_xticks(np.arange(len(new_paramsn.columns)))
ax.set_xticklabels(new_paramsn.columns, rotation=90)

ax.set_yticks([-1.5, 0, 1.5])

plt.savefig("U.pdf")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
A0=[]
A1=[]
A2=[]
A3=[]
A4=[]
A5=[]
A6=[]
A7=[]
A8=[]

BBB=[ 'x_na','y_na',  'g_unav', 'g_cav', 'g_lena','g_lek', 'g_kvhh', 'g_kna','t_na']

S0 = pd.read_csv("OD0.csv")
T0 = pd.read_csv("OD10.csv")
S1 = pd.read_csv("OD1.csv")
T1 = pd.read_csv("OD11.csv")
S2 = pd.read_csv("OD2.csv")
T2 = pd.read_csv("OD12.csv")
S3 = pd.read_csv("OD3.csv")
T3 = pd.read_csv("OD13.csv")
S4 = pd.read_csv("OD4.csv")
T4 = pd.read_csv("OD14.csv")
S5 = pd.read_csv("OD5.csv")
T5 = pd.read_csv("OD15.csv")
S6 = pd.read_csv("OD6.csv")
T6 = pd.read_csv("OD16.csv")
S7 = pd.read_csv("OD7.csv")
T7 = pd.read_csv("OD17.csv")
S8 = pd.read_csv("OD8.csv")
T8 = pd.read_csv("OD18.csv")

for i in tqdm(range(len(S6["u1"]))):
    if(i==0):
        continue
    if (S6["u1"][i] == 0 or S6["u1"][i] == -1 or T6["u1"][i] == 0 or T6["d1"][i] == -1):
        continue
    A6.append((T6["d1"][i]) / (S6["d1"][i]))

for i in tqdm(range(len(S7["u1"]))):
    if(i==0):
        continue
    if (S7["u1"][i] == 0 or S7["u1"][i] == -1 or T7["u1"][i] == 0 or T7["d1"][i] == -1 or i>=len(S7["u1"])):
        continue
    A7.append(( T7["d1"][i]) / (S7["d1"][i]))
    
for i in tqdm(range(len(S1["u1"]))):
    if(i==0):
        continue
    if (S1["u1"][i] == 0 or S1["u1"][i] == -1 or T1["u1"][i] == 0 or T1["d1"][i] == -1 or i>=len(S1["u1"])):
        continue
    A1.append((T1["d1"][i]) / (S1["d1"][i]))
    
for i in tqdm(range(len(S5["u1"]))):
    if(i==0):
        continue
    if (S5["u1"][i] == 0 or S5["u1"][i] == -1 or T5["u1"][i] == 0 or T5["d1"][i] == -1 or i>=len(S5["u1"])):
        continue
    A5.append((T5["d1"][i]) / (S5["d1"][i]))
    
for i in tqdm(range(len(S0["u1"]))):
    if(i==0):
        continue
    if (S0["u1"][i] == 0 or S0["u1"][i] == -1 or T0["u1"][i] == 0 or T0["d1"][i] == -1 or i>=len(S0["u1"])):
        continue
    A0.append((T0["d1"][i]) / ( S0["d1"][i]))
    
for i in tqdm(range(len(S2["u1"]))):
    if(i==0):
        continue
    if (S2["u1"][i] == 0 or S2["u1"][i] == -1 or T2["u1"][i] == 0 or T2["d1"][i] == -1 or i>=len(S2["u1"])):
        continue
    A2.append((T2["d1"][i]) / ( S2["d1"][i]))
    
for i in tqdm(range(len(S4["u1"]))):
    if(i==0):
        continue
    if (S4["u1"][i] == 0 or S4["u1"][i] == -1 or T4["u1"][i] == 0 or T4["d1"][i] == -1 or i>=len(S4["u1"])):
        continue
    A4.append((T4["d1"][i]) / (S4["d1"][i]))
    

for i in tqdm(range(len(S3["u1"]))):
    if(i==0):
        continue
    if (S3["u1"][i] == 0 or S3["u1"][i] == -1 or T3["u1"][i] == 0 or T3["d1"][i] == -1 or i>=len(S3["u1"])):
        continue
    A3.append(( T3["d1"][i]) / (S3["d1"][i]))
    
    
for i in tqdm(range(len(S8["u1"]))):
    if(i==0):
        continue
    if (S8["u1"][i] == 0 or S8["u1"][i] == -1 or T8["u1"][i] == 0 or T8["d1"][i] == -1 or i>=len(S8["u1"])):
        continue
    A8.append((T8["d1"][i]) / (S8["d1"][i]))





    
G1=[A6,A7,A1,A5,A0,A2,A4,A3,A8] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsp=N1

fig=plt.figure(figsize=(10,10))
ax=sns.stripplot(data=new_paramsp)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            data=new_paramsp,
            showfliers=False,
            showbox=False,
            showcaps=False,
            )
# 描画
# Out:
# 100%|██████████| 1132/1132 [00:00<00:00, 22207.76it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 15396.13it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 12660.77it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 13970.32it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 12035.00it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 6060.28it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 18233.37it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 14896.05it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 13716.38it/s]
# <AxesSubplot:>

# %%
def normalize_rgb(rgb):
    return tuple(component / 255 for component in rgb)
G1=[np.log10(A6),np.log10(A7),np.log10(A1),np.log10(A5),np.log10(A0),np.log10(A2),np.log10(A4),np.log10(A3),np.log10(A8)] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsn=N1

new_paramsn = new_paramsn.select_dtypes(include=[np.number])
CC=[(202,28,29), (213,94,22), (26,47,111), (128,27,115), (245,233,40)]
COLOR1=[CC[0],CC[0],CC[0],CC[1],CC[2],CC[2],CC[3],CC[3],CC[4]]
fig, ax = plt.subplots(figsize=(16, 9))
count=0

for index, column in enumerate(new_paramsn.columns):
    y = new_paramsn[column]
    x = np.random.normal(loc=index, scale=0.04, size=len(y))
    ax.scatter(x, y, c=normalize_rgb(COLOR1[count]), zorder=5)
    count=count+1
    
for index, column in enumerate(new_paramsn.columns):
    mean_value = new_paramsn[column].mean()
    ax.axhline(y=mean_value, color='k', linestyle='-', linewidth=0.5, xmin=index/len(new_paramsn.columns), xmax=(index+1)/len(new_paramsn.columns))

ax.set_xticks(np.arange(len(new_paramsn.columns)))
ax.set_xticklabels(new_paramsn.columns, rotation=90)

ax.set_yticks([-1.5, 0, 1.5])
plt.savefig("D.pdf")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
A0=[]
A1=[]
A2=[]
A3=[]
A4=[]
A5=[]
A6=[]
A7=[]
A8=[]

BBB=[ 'x_na','y_na',  'g_unav', 'g_cav', 'g_lena','g_lek', 'g_kvhh', 'g_kna','t_na']

S0 = pd.read_csv("OD0.csv")
T0 = pd.read_csv("OD10.csv")
S1 = pd.read_csv("OD1.csv")
T1 = pd.read_csv("OD11.csv")
S2 = pd.read_csv("OD2.csv")
T2 = pd.read_csv("OD12.csv")
S3 = pd.read_csv("OD3.csv")
T3 = pd.read_csv("OD13.csv")
S4 = pd.read_csv("OD4.csv")
T4 = pd.read_csv("OD14.csv")
S5 = pd.read_csv("OD5.csv")
T5 = pd.read_csv("OD15.csv")
S6 = pd.read_csv("OD6.csv")
T6 = pd.read_csv("OD16.csv")
S7 = pd.read_csv("OD7.csv")
T7 = pd.read_csv("OD17.csv")
S8 = pd.read_csv("OD8.csv")
T8 = pd.read_csv("OD18.csv")

for i in tqdm(range(len(S6["u1"]))):
    if(i==0):
        continue
    if (S6["u1"][i] == 0 or S6["u1"][i] == -1 or T6["u1"][i] == 0 or T6["d1"][i] == -1):
        continue
    A6.append((T6["max"][i]-T6["min"][i]) / (S6["max"][i]-S6["min"][i]))
    if((T6["max"][i]-T6["min"][i]) / (S6["max"][i]-S6["min"][i])>200):
        print(i)
    
    
for i in tqdm(range(len(S7["u1"]))):
    if(i==0):
        continue
    if (S7["u1"][i] == 0 or S7["u1"][i] == -1 or T7["u1"][i] == 0 or T7["d1"][i] == -1):
        continue
    A7.append((T7["max"][i]-T7["min"][i]) / (S7["max"][i]-S7["min"][i]))
    

for i in tqdm(range(len(S1["u1"]))):
    if(i==0):
        continue
    if (S1["u1"][i] == 0 or S1["u1"][i] == -1 or T1["u1"][i] == 0 or T1["d1"][i] == -1):
        continue
    A1.append((T1["max"][i]-T1["min"][i]) / (S1["max"][i]-S1["min"][i]))
    
for i in tqdm(range(len(S5["u1"]))):
    if(i==0):
        continue
    if (S5["u1"][i] == 0 or S5["u1"][i] == -1 or T5["u1"][i] == 0 or T5["d1"][i] == -1):
        continue
    A5.append((T5["max"][i]-T5["min"][i]) / (S5["max"][i]-S5["min"][i]))
    
for i in tqdm(range(len(S0["u1"]))):
    if(i==0):
        continue
    if (S0["u1"][i] == 0 or S0["u1"][i] == -1 or T0["u1"][i] == 0 or T0["d1"][i] == -1 or i>=len(S0["u1"])):
        continue
    A0.append((T0["max"][i]-T0["min"][i]) / (S0["max"][i]-S0["min"][i]))
    
for i in tqdm(range(len(S2["u1"]))):
    if(i==0):
        continue
    if (S2["u1"][i] == 0 or S2["u1"][i] == -1 or T2["u1"][i] == 0 or T2["d1"][i] == -1):
        continue
    A2.append((T2["max"][i]-T2["min"][i]) / (S2["max"][i]-S2["min"][i]))    
    

for i in tqdm(range(len(S4["u1"]))):
    if(i==0):
        continue
    if (S4["u1"][i] == 0 or S4["u1"][i] == -1 or T4["u1"][i] == 0 or T4["d1"][i] == -1):
        continue
    A4.append((T4["max"][i]-T4["min"][i]) / (S4["max"][i]-S4["min"][i]))
    
for i in tqdm(range(len(S3["u1"]))):
    if(i==0):
        continue
    if (S3["u1"][i] == 0 or S3["u1"][i] == -1 or T3["u1"][i] == 0 or T3["d1"][i] == -1):
        continue
    A3.append((T3["max"][i]-T3["min"][i]) / (S3["max"][i]-S3["min"][i]))

    
for i in tqdm(range(len(S8["u1"]))):
    if(i==0):
        continue
    if (S8["u1"][i] == 0 or S8["u1"][i] == -1 or T8["u1"][i] == 0 or T8["d1"][i] == -1):
        continue
    A8.append((T8["max"][i]-T8["min"][i]) / (S8["max"][i]-S8["min"][i]))



    
G1=[A6,A7,A1,A5,A0,A2,A4,A3,A8] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsp=N1

fig=plt.figure(figsize=(10,10))
ax=sns.stripplot(data=new_paramsp)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            data=new_paramsp,
            showfliers=False,
            showbox=False,
            showcaps=False,
            )
# Out:
# 100%|██████████| 1132/1132 [00:00<00:00, 11789.21it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 10658.54it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 13603.28it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 9993.10it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 6256.69it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 13826.14it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 16896.51it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 21657.60it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 10098.93it/s]
# <AxesSubplot:>

# %%
def normalize_rgb(rgb):
    return tuple(component / 255 for component in rgb)
G1=[np.log10(A6),np.log10(A7),np.log10(A1),np.log10(A5),np.log10(A0),np.log10(A2),np.log10(A4),np.log10(A3),np.log10(A8)] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsn=N1

new_paramsn = new_paramsn.select_dtypes(include=[np.number])
CC=[(202,28,29), (213,94,22), (26,47,111), (128,27,115), (245,233,40)]
COLOR1=[CC[0],CC[0],CC[0],CC[1],CC[2],CC[2],CC[3],CC[3],CC[4]]
fig, ax = plt.subplots(figsize=(16, 9))
count=0

for index, column in enumerate(new_paramsn.columns):
    y = new_paramsn[column]
    x = np.random.normal(loc=index, scale=0.04, size=len(y))
    ax.scatter(x, y, c=normalize_rgb(COLOR1[count]), zorder=5)
    count=count+1
    
for index, column in enumerate(new_paramsn.columns):
    mean_value = new_paramsn[column].mean()
    ax.axhline(y=mean_value, color='k', linestyle='-', linewidth=0.5, xmin=index/len(new_paramsn.columns), xmax=(index+1)/len(new_paramsn.columns))

ax.set_xticks(np.arange(len(new_paramsn.columns)))
ax.set_xticklabels(new_paramsn.columns, rotation=90)

ax.set_yticks([-1.5, 0, 1.5])

plt.savefig("O.pdf")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
A0=[]
A1=[]
A2=[]
A3=[]
A4=[]
A5=[]
A6=[]
A7=[]
A8=[]

BBB=[ 'x_na','y_na',  'g_unav', 'g_cav', 'g_lena','g_lek', 'g_kvhh', 'g_kna','t_na']

S0 = pd.read_csv("OD0.csv")
T0 = pd.read_csv("OD10.csv")
S1 = pd.read_csv("OD1.csv")
T1 = pd.read_csv("OD11.csv")
S2 = pd.read_csv("OD2.csv")
T2 = pd.read_csv("OD12.csv")
S3 = pd.read_csv("OD3.csv")
T3 = pd.read_csv("OD13.csv")
S4 = pd.read_csv("OD4.csv")
T4 = pd.read_csv("OD14.csv")
S5 = pd.read_csv("OD5.csv")
T5 = pd.read_csv("OD15.csv")
S6 = pd.read_csv("OD6.csv")
T6 = pd.read_csv("OD16.csv")
S7 = pd.read_csv("OD7.csv")
T7 = pd.read_csv("OD17.csv")
S8 = pd.read_csv("OD8.csv")
T8 = pd.read_csv("OD18.csv")

for i in tqdm(range(len(S6["u1"]))):
    if(i==0):
        continue
    if (S6["u1"][i] == 0 or S6["u1"][i] == -1 or T6["u1"][i] == 0 or T6["d1"][i] == -1):
        continue
    A6.append((T6["mean"][i]) / (S6["mean"][i]))

for i in tqdm(range(len(S7["u1"]))):
    if(i==0):
        continue
    if (S7["u1"][i] == 0 or S7["u1"][i] == -1 or T7["u1"][i] == 0 or T7["d1"][i] == -1 or i>=len(S7["u1"])):
        continue
    A7.append(( T7["mean"][i]) / (S7["mean"][i]))
    
for i in tqdm(range(len(S1["u1"]))):
    if(i==0):
        continue
    if (S1["u1"][i] == 0 or S1["u1"][i] == -1 or T1["u1"][i] == 0 or T1["d1"][i] == -1 or i>=len(S1["u1"])):
        continue
    A1.append((T1["mean"][i]) / (S1["mean"][i]))
    

for i in tqdm(range(len(S5["u1"]))):
    if(i==0):
        continue
    if (S5["u1"][i] == 0 or S5["u1"][i] == -1 or T5["u1"][i] == 0 or T5["d1"][i] == -1 or i>=len(S5["u1"])):
        continue
    A5.append((T5["mean"][i]) / (S5["mean"][i]))
    
    

for i in tqdm(range(len(S0["u1"]))):
    if(i==0):
        continue
    if (S0["u1"][i] == 0 or S0["u1"][i] == -1 or T0["u1"][i] == 0 or T0["d1"][i] == -1 or i>=len(S0["u1"])):
        continue
    A0.append((T0["mean"][i]) / ( S0["mean"][i]))
    
for i in tqdm(range(len(S2["u1"]))):
    if(i==0):
        continue
    if (S2["u1"][i] == 0 or S2["u1"][i] == -1 or T2["u1"][i] == 0 or T2["d1"][i] == -1 or i>=len(S2["u1"])):
        continue
    A2.append((T2["mean"][i]) / ( S2["mean"][i]))
    
    
for i in tqdm(range(len(S4["u1"]))):
    if(i==0):
        continue
    if (S4["u1"][i] == 0 or S4["u1"][i] == -1 or T4["u1"][i] == 0 or T4["d1"][i] == -1 or i>=len(S4["u1"])):
        continue
    A4.append((T4["mean"][i]) / (S4["mean"][i]))
    
    
for i in tqdm(range(len(S3["u1"]))):
    if(i==0):
        continue
    if (S3["u1"][i] == 0 or S3["u1"][i] == -1 or T3["u1"][i] == 0 or T3["d1"][i] == -1 or i>=len(S3["u1"])):
        continue
    A3.append(( T3["mean"][i]) / (S3["mean"][i]))
    
    
for i in tqdm(range(len(S8["u1"]))):
    if(i==0):
        continue
    if (S8["u1"][i] == 0 or S8["u1"][i] == -1 or T8["u1"][i] == 0 or T8["d1"][i] == -1 or i>=len(S8["u1"])):
        continue
    A8.append((T8["mean"][i]) / (S8["mean"][i]))



    
G1=[A6,A7,A1,A5,A0,A2,A4,A3,A8] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsp=N1

fig=plt.figure(figsize=(10,10))
ax=sns.stripplot(data=new_paramsp)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            data=new_paramsp,
            showfliers=False,
            showbox=False,
            showcaps=False,
            )
# 描画
# Out:
# 100%|██████████| 1132/1132 [00:00<00:00, 15891.50it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 22126.72it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 9748.45it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 15360.82it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 12884.85it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 18496.47it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 15586.27it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 17829.27it/s]
# 100%|██████████| 1132/1132 [00:00<00:00, 22995.51it/s]
# <AxesSubplot:>

# %%
def normalize_rgb(rgb):
    return tuple(component / 255 for component in rgb)
G1=[np.log10(A6),np.log10(A7),np.log10(A1),np.log10(A5),np.log10(A0),np.log10(A2),np.log10(A4),np.log10(A3),np.log10(A8)] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsn=N1

new_paramsn = new_paramsn.select_dtypes(include=[np.number])
CC=[(202,28,29), (213,94,22), (26,47,111), (128,27,115), (245,233,40)]
COLOR1=[CC[0],CC[0],CC[0],CC[1],CC[2],CC[2],CC[3],CC[3],CC[4]]

fig, ax = plt.subplots(figsize=(16, 9))
count=0

for index, column in enumerate(new_paramsn.columns):
    y = new_paramsn[column]
    x = np.random.normal(loc=index, scale=0.04, size=len(y))
    ax.scatter(x, y, c=normalize_rgb(COLOR1[count]), zorder=5)
    count=count+1
    
for index, column in enumerate(new_paramsn.columns):
    mean_value = new_paramsn[column].mean()
    ax.axhline(y=mean_value, color='k', linestyle='-', linewidth=0.5, xmin=index/len(new_paramsn.columns), xmax=(index+1)/len(new_paramsn.columns))

ax.set_xticks(np.arange(len(new_paramsn.columns)))
ax.set_xticklabels(new_paramsn.columns, rotation=90)

ax.set_yticks([-1.5, 0, 1.5])

plt.savefig("I.pdf")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
