# %%
import os
import sys
import requests
from datetime import datetime 
from multiprocessing import Pool
import numpy as  np
import pandas as pd
from pathlib import Path
import pickle
from tqdm import tqdm
from time import time
from typing import Dict, List, Optional
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
plt.rcParams['font.family'] = 'Arial'

# %%
A0=[]
A1=[]
A2=[]
A3=[]
A4=[]
A5=[]
A6=[]
A7=[]
A8=[]
A9=[]
A10=[]
A11=[]
A12=[]
A13=[]
A15=[]
A16=[]
A17=[]
A18=[]

BBB=['x_na', 'y_na', 'g_nap', 'g_nav', 'g_unav', 'g_cav','g_kvhh', 'g_kva', 'g_kir', 'g_kvsi', 'g_kca', 'g_kna',  'g_lek', 'g_lena', 't_ca', 't_na', 'g_ampa', 'g_nmda']
S0 = pd.read_csv("ODa0.csv")
T0 = pd.read_csv("ODa10.csv")
S1 = pd.read_csv("ODa1.csv")
T1 = pd.read_csv("ODa11.csv")
S2 = pd.read_csv("ODa2.csv")
T2 = pd.read_csv("ODa12.csv")
S3 = pd.read_csv("ODa3.csv")
T3 = pd.read_csv("ODa13.csv")
S4 = pd.read_csv("ODa4.csv")
T4 = pd.read_csv("ODa14.csv")
S5 = pd.read_csv("ODa5.csv")
T5 = pd.read_csv("ODa15.csv")
S6 = pd.read_csv("ODa6.csv")
T6 = pd.read_csv("ODa16.csv")
S7 = pd.read_csv("ODa7.csv")
T7 = pd.read_csv("ODa17.csv")
S8 = pd.read_csv("ODa8.csv")
T8 = pd.read_csv("ODa18.csv")
S9 = pd.read_csv("ODa9.csv")
T9 = pd.read_csv("ODa19.csv")

S10 = pd.read_csv("OD10.csv")
T10 = pd.read_csv("OD110.csv")
S11 = pd.read_csv("OD11.csv")
T11 = pd.read_csv("OD111.csv")
S12 = pd.read_csv("OD12.csv")
T12 = pd.read_csv("OD112.csv")
S13 = pd.read_csv("OD13.csv")
T13 = pd.read_csv("OD113.csv")

S15 = pd.read_csv("OD15.csv")
T15 = pd.read_csv("OD115.csv")
S16 = pd.read_csv("OD16.csv")
T16 = pd.read_csv("OD116.csv")
S17 = pd.read_csv("OD17.csv")
T17 = pd.read_csv("OD117.csv")
S18 = pd.read_csv("OD18.csv")
T18 = pd.read_csv("OD118.csv")

from tqdm import tqdm

for i in tqdm(range(len(S0["u1"]))):
    if(i==0):
        continue
    if (S0["u1"][i] == 0 or S0["u1"][i] == -1 or T0["u1"][i] == 0 or T0["d1"][i] == -1):
        continue
    A0.append((T0["u1"][i] + T0["d1"][i]) / (S0["u1"][i] + S0["d1"][i]))


for i in tqdm(range(len(S1["u1"]))):
    if i == 0:
        continue
    if (S1["u1"][i] == 0 or S1["u1"][i] == -1 or T1["u1"][i] == 0 or T1["d1"][i] == -1):
        continue
    A1.append((T1["u1"][i] + T1["d1"][i]) / (S1["u1"][i] + S1["d1"][i]))

for i in tqdm(range(len(S2["u1"]))):
    if i == 0:
        continue
    if (S2["u1"][i] == 0 or S2["u1"][i] == -1 or T2["u1"][i] == 0 or T2["d1"][i] == -1):
        continue
    A2.append((T2["u1"][i] + T2["d1"][i]) / (S2["u1"][i] + S2["d1"][i]))

for i in tqdm(range(len(S3["u1"]))):
    if i == 0:
        continue
    if (S3["u1"][i] == 0 or S3["u1"][i] == -1 or T3["u1"][i] == 0 or T3["d1"][i] == -1):
        continue
    A3.append((T3["u1"][i] + T3["d1"][i]) / (S3["u1"][i] + S3["d1"][i]))

for i in tqdm(range(len(S4["u1"]))):
    if i == 0:
        continue
    if (S4["u1"][i] == 0 or S4["u1"][i] == -1 or T4["u1"][i] == 0 or T4["d1"][i] == -1):
        continue
    A4.append((T4["u1"][i] + T4["d1"][i]) / (S4["u1"][i] + S4["d1"][i]))

for i in tqdm(range(len(S5["u1"]))):
    if i == 0:
        continue
    if (S5["u1"][i] == 0 or S5["u1"][i] == -1 or T5["u1"][i] == 0 or T5["d1"][i] == -1):
        continue
    A5.append((T5["u1"][i] + T5["d1"][i]) / (S5["u1"][i] + S5["d1"][i]))

for i in tqdm(range(len(S6["u1"]))):
    if i == 0:
        continue
    if (S6["u1"][i] == 0 or S6["u1"][i] == -1 or T6["u1"][i] ==0 or T6["d1"][i] == -1):
        continue
    A6.append((T6["u1"][i] + T6["d1"][i]) / (S6["u1"][i] + S6["d1"][i]))

for i in tqdm(range(len(S7["u1"]))):
    if i == 0:
        continue
    if (S7["u1"][i] == 0 or S7["u1"][i] == -1 or T7["u1"][i] == 0 or T7["d1"][i] == -1):
        continue
    A7.append((T7["u1"][i] + T7["d1"][i]) / (S7["u1"][i] + S7["d1"][i]))

for i in tqdm(range(len(S8["u1"]))):
    if i == 0:
        continue
    if (S8["u1"][i] == 0 or S8["u1"][i] == -1 or T8["u1"][i] == 0 or T8["d1"][i] == -1):
        continue
    A8.append((T8["u1"][i] + T8["d1"][i]) / (S8["u1"][i] + S8["d1"][i]))

for i in tqdm(range(len(S9["u1"]))):
    if i == 0:
        continue
    if (S9["u1"][i] == 0 or S9["u1"][i] == -1 or T9["u1"][i] == 0 or T9["d1"][i] == -1):
        continue
    A9.append((T9["u1"][i] + T9["d1"][i]) / (S9["u1"][i] + S9["d1"][i]))

for i in tqdm(range(len(S10["u1"]))):
    if i == 0:
        continue
    if (S10["u1"][i] == 0 or S10["u1"][i] == -1 or T10["u1"][i] ==0 or T10["d1"][i] == -1):
        continue
    A10.append((T10["u1"][i] + T10["d1"][i]) / (S10["u1"][i] + S10["d1"][i]))

for i in tqdm(range(len(S11["u1"]))):
    if i == 0:
        continue
    if (S11["u1"][i] == 0 or S11["u1"][i] == -1 or T11["u1"][i] == 0 or T11["d1"][i] == -1):
        continue
    A11.append((T11["u1"][i] + T11["d1"][i]) / (S11["u1"][i] + S11["d1"][i]))

for i in tqdm(range(len(S12["u1"]))):
    if i == 0:
        continue
    if (S12["u1"][i] == 0 or S12["u1"][i] == -1 or T12["u1"][i] == 0 or T12["d1"][i] == -1):
        continue
    A12.append((T12["u1"][i] + T12["d1"][i]) / (S12["u1"][i] + S12["d1"][i]))

for i in tqdm(range(len(S13["u1"]))):
    if i == 0:
        continue
    if (S13["u1"][i] == 0 or S13["u1"][i] == -1 or T13["u1"][i] == 0 or T13["d1"][i] == -1):
        continue
    A13.append((T13["u1"][i] + T13["d1"][i]) / (S13["u1"][i] + S13["d1"][i]))


for i in tqdm(range(len(S15["u1"]))):
    if i == 0:
        continue
    if (S15["u1"][i] ==0 or S15["u1"][i] == -1 or T15["u1"][i] ==0 or T15["d1"][i] == -1):
        continue
    A15.append((T15["u1"][i] + T15["d1"][i]) / (S15["u1"][i] + S15["d1"][i]))

for i in tqdm(range(len(S16["u1"]))):
    if i == 0:
        continue
    if (S16["u1"][i] ==0 or S16["u1"][i] == -1 or T16["u1"][i] ==0 or T16["d1"][i] == -1):
        continue
    A16.append((T16["u1"][i] + T16["d1"][i]) / (S16["u1"][i] + S16["d1"][i]))

for i in tqdm(range(len(S17["u1"]))):
    if i == 0:
        continue
    if (S17["u1"][i] ==0 or S17["u1"][i] == -1 or T17["u1"][i] ==0 or T17["d1"][i] == -1):
        continue
    A17.append((T17["u1"][i] + T17["d1"][i]) / (S17["u1"][i] + S17["d1"][i]))

for i in tqdm(range(len(S18["u1"]))):
    if i == 0:
        continue
    if (S18["u1"][i] ==0 or S18["u1"][i] == -1 or T18["u1"][i] ==0 or T18["d1"][i] == -1):
        continue
    A18.append((T18["u1"][i] + T18["d1"][i]) / (S18["u1"][i] + S18["d1"][i]))




    
G1=[A17,A18, A8,A2, A10,A6, A3,A4,A9,A5,A7,A11,A0,A1,A15,A16,A12,A13]
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsp=N1

# %%
new_paramsp

# %%
fig=plt.figure(figsize=(10,10))
ax=sns.stripplot(data=new_paramsp)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            data=new_paramsp,
            showfliers=False,
            showbox=False,
            showcaps=False,
            )

# %%
def normalize_rgb(rgb):
    return tuple(component / 255 for component in rgb)
G1=[np.log10(A17),np.log10(A18),np.log10(A8),np.log10(A2),np.log10(A6), np.log10(A10),np.log10(A3),np.log10(A4),np.log10(A9),np.log10(A5),np.log10(A7), np.log10(A11),np.log10(A0),np.log10(A1), np.log10(A15),np.log10(A16),np.log10(A12),np.log10(A13)] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsn=N1



new_paramsn = new_paramsn.select_dtypes(include=[np.number])
CC=[(202,28,29), (213,94,22), (26,47,111), (128,27,115), (245,233,40),  (0,153,68)]
COLOR1=[CC[0],CC[0],CC[0],CC[0],CC[0], CC[1],CC[2],CC[2],CC[2], CC[2], CC[2], CC[2], CC[3],CC[3], CC[4], CC[4], CC[5], CC[5]]

fig, ax = plt.subplots(figsize=(36, 9))
count=0

for index, column in enumerate(new_paramsn.columns):
    y = new_paramsn[column]
    x = np.random.normal(loc=index, scale=0.04, size=len(y))
    ax.scatter(x, y, c=normalize_rgb(COLOR1[count]), zorder=5)
    count=count+1
    

for index, column in enumerate(new_paramsn.columns):
    mean_value = new_paramsn[column].mean()
    ax.axhline(y=mean_value, color='k', linestyle='-', linewidth=0.5, xmin=index/len(new_paramsn.columns), xmax=(index+1)/len(new_paramsn.columns))

ax.set_xticks(np.arange(len(new_paramsn.columns)))
ax.set_xticklabels(new_paramsn.columns, rotation=90)

ax.set_yticks([-1.5, 0, 1.5])
plt.savefig("UD.pdf")

# %%
A0=[]
A1=[]
A2=[]
A3=[]
A4=[]
A5=[]
A6=[]
A7=[]
A8=[]
A9=[]
A10=[]
A11=[]
A12=[]
A13=[]
A15=[]
A16=[]
A17=[]
A18=[]

BBB=['x_na', 'y_na', 'g_nap', 'g_nav', 'g_unav', 'g_cav', 'g_kvhh', 'g_kva', 'g_kir', 'g_kvsi', 'g_kca', 'g_kna',  'g_lek', 'g_lena', 't_ca', 't_na', 'g_ampa', 'g_nmda']

S0 = pd.read_csv("ODa0.csv")
T0 = pd.read_csv("ODa10.csv")
S1 = pd.read_csv("ODa1.csv")
T1 = pd.read_csv("ODa11.csv")
S2 = pd.read_csv("ODa2.csv")
T2 = pd.read_csv("ODa12.csv")
S3 = pd.read_csv("ODa3.csv")
T3 = pd.read_csv("ODa13.csv")
S4 = pd.read_csv("ODa4.csv")
T4 = pd.read_csv("ODa14.csv")
S5 = pd.read_csv("ODa5.csv")
T5 = pd.read_csv("ODa15.csv")
S6 = pd.read_csv("ODa6.csv")
T6 = pd.read_csv("ODa16.csv")
S7 = pd.read_csv("ODa7.csv")
T7 = pd.read_csv("ODa17.csv")
S8 = pd.read_csv("ODa8.csv")
T8 = pd.read_csv("ODa18.csv")
S9 = pd.read_csv("ODa9.csv")
T9 = pd.read_csv("ODa19.csv")

S10 = pd.read_csv("OD10.csv")
T10 = pd.read_csv("OD110.csv")
S11 = pd.read_csv("OD11.csv")
T11 = pd.read_csv("OD111.csv")
S12 = pd.read_csv("OD12.csv")
T12 = pd.read_csv("OD112.csv")
S13 = pd.read_csv("OD13.csv")
T13 = pd.read_csv("OD113.csv")

S15 = pd.read_csv("OD15.csv")
T15 = pd.read_csv("OD115.csv")
S16 = pd.read_csv("OD16.csv")
T16 = pd.read_csv("OD116.csv")
S17 = pd.read_csv("OD17.csv")
T17 = pd.read_csv("OD117.csv")
S18 = pd.read_csv("OD18.csv")
T18 = pd.read_csv("OD118.csv")


for i in tqdm(range(len(S0["u1"]))):
    if i == 0:
        continue
    if (S0["u1"][i] == 0 or S0["u1"][i] == -1 or T0["u1"][i] == 0 or T0["d1"][i] == -1):
        continue
    A0.append((T0["u1"][i]) / (S0["u1"][i]))

for i in tqdm(range(len(S1["u1"]))):
    if i == 0:
        continue
    if (S1["u1"][i] == 0 or S1["u1"][i] == -1 or T1["u1"][i] == 0 or T1["d1"][i] == -1):
        continue
    A1.append((T1["u1"][i]) / (S1["u1"][i]))

for i in tqdm(range(len(S2["u1"]))):
    if i == 0:
        continue
    if (S2["u1"][i] == 0 or S2["u1"][i] == -1 or T2["u1"][i] == 0 or T2["d1"][i] == -1):
        continue
    A2.append((T2["u1"][i]) / (S2["u1"][i]))

for i in tqdm(range(len(S3["u1"]))):
    if i == 0:
        continue
    if (S3["u1"][i] == 0 or S3["u1"][i] == -1 or T3["u1"][i] == 0 or T3["d1"][i] == -1):
        continue
    A3.append((T3["u1"][i]) / (S3["u1"][i]))

for i in tqdm(range(len(S4["u1"]))):
    if i == 0:
        continue
    if (S4["u1"][i] == 0 or S4["u1"][i] == -1 or T4["u1"][i] == 0 or T4["d1"][i] == -1):
        continue
    A4.append((T4["u1"][i]) / (S4["u1"][i]))

for i in tqdm(range(len(S5["u1"]))):
    if i == 0:
        continue
    if (S5["u1"][i] == 0 or S5["u1"][i] == -1 or T5["u1"][i] == 0 or T5["d1"][i] == -1):
        continue
    A5.append((T5["u1"][i]) / (S5["u1"][i]))

for i in tqdm(range(len(S6["u1"]))):
    if i == 0:
        continue
    if (S6["u1"][i] == 0 or S6["u1"][i] == -1 or T6["u1"][i] == 0 or T6["d1"][i] == -1):
        continue
    A6.append((T6["u1"][i]) / (S6["u1"][i]))

for i in tqdm(range(len(S7["u1"]))):
    if i == 0:
        continue
    if (S7["u1"][i] == 0 or S7["u1"][i] == -1 or T7["u1"][i] == 0 or T7["d1"][i] == -1):
        continue
    A7.append((T7["u1"][i]) / (S7["u1"][i]))

for i in tqdm(range(len(S8["u1"]))):
    if i == 0:
        continue
    if (S8["u1"][i] == 0 or S8["u1"][i] == -1 or T8["u1"][i] == 0 or T8["d1"][i] == -1):
        continue
    A8.append((T8["u1"][i]) / (S8["u1"][i]))

for i in tqdm(range(len(S9["u1"]))):
    if i == 0:
        continue
    if (S9["u1"][i] == 0 or S9["u1"][i] == -1 or T9["u1"][i] == 0 or T9["d1"][i] == -1):
        continue
    A9.append((T9["u1"][i]) / (S9["u1"][i]))

for i in tqdm(range(len(S10["u1"]))):
    if i == 0:
        continue
    if (S10["u1"][i] == 0 or S10["u1"][i] == -1 or T10["u1"][i] == 0 or T10["d1"][i] == -1):
        continue
    A10.append((T10["u1"][i]) / (S10["u1"][i]))

for i in tqdm(range(len(S11["u1"]))):
    if i == 0:
        continue
    if (S11["u1"][i] == 0 or S11["u1"][i] == -1 or T11["u1"][i] == 0 or T11["d1"][i] == -1):
        continue
    A11.append((T11["u1"][i]) / (S11["u1"][i]))

for i in tqdm(range(len(S12["u1"]))):
    if i == 0:
        continue
    if (S12["u1"][i] == 0 or S12["u1"][i] == -1 or T12["u1"][i] == 0 or T12["d1"][i] == -1):
        continue
    A12.append((T12["u1"][i]) / (S12["u1"][i]))

for i in tqdm(range(len(S13["u1"]))):
    if i == 0:
        continue
    if (S13["u1"][i] == 0 or S13["u1"][i] == -1 or T13["u1"][i] == 0 or T13["d1"][i] == -1):
        continue
    A13.append((T13["u1"][i]) / (S13["u1"][i]))


    
for i in tqdm(range(len(S15["u1"]))):
    if i == 0:
        continue
    if (S15["u1"][i] == 0 or S15["u1"][i] == -1 or T15["u1"][i] == 0 or T15["d1"][i] == -1):
        continue
    A15.append((T15["u1"][i]) / (S15["u1"][i]))
    
for i in tqdm(range(len(S16["u1"]))):
    if i == 0:
        continue
    if (S16["u1"][i] == 0 or S16["u1"][i] == -1 or T16["u1"][i] == 0 or T16["d1"][i] == -1):
        continue
    A16.append((T16["u1"][i]) / (S16["u1"][i]))
    
for i in tqdm(range(len(S17["u1"]))):
    if i == 0:
        continue
    if (S17["u1"][i] == 0 or S17["u1"][i] == -1 or T17["u1"][i] == 0 or T17["d1"][i] == -1):
        continue
    A17.append((T17["u1"][i]) / (S17["u1"][i]))
    
for i in tqdm(range(len(S18["u1"]))):
    if i == 0:
        continue
    if (S18["u1"][i] == 0 or S18["u1"][i] == -1 or T18["u1"][i] == 0 or T18["d1"][i] == -1):
        continue
    A18.append((T18["u1"][i]) / (S18["u1"][i]))




    
G1=[A17,A18, A8,A2, A10,A6, A3,A4,A9,A5,A7,A11,A0,A1,A15,A16,A12,A13]
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsp=N1

fig=plt.figure(figsize=(10,10))
ax=sns.stripplot(data=new_paramsp)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            data=new_paramsp,
            showfliers=False,
            showbox=False,
            showcaps=False,
            )
# 描画

# %%
def normalize_rgb(rgb):
    return tuple(component / 255 for component in rgb)
G1=[np.log10(A17),np.log10(A18),np.log10(A8),np.log10(A2),np.log10(A6), np.log10(A10),np.log10(A3),np.log10(A4),np.log10(A9),np.log10(A5),np.log10(A7), np.log10(A11),np.log10(A0),np.log10(A1), np.log10(A15),np.log10(A16),np.log10(A12),np.log10(A13)] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsn=N1


new_paramsn = new_paramsn.select_dtypes(include=[np.number])
CC=[(202,28,29), (213,94,22), (26,47,111), (128,27,115), (245,233,40),  (0,153,68)]
COLOR1=[CC[0],CC[0],CC[0],CC[0],CC[0], CC[1],CC[2],CC[2],CC[2], CC[2], CC[2], CC[2], CC[3],CC[3], CC[4], CC[4], CC[5], CC[5]]

fig, ax = plt.subplots(figsize=(36, 9))
count=0

for index, column in enumerate(new_paramsn.columns):
    y = new_paramsn[column]
    x = np.random.normal(loc=index, scale=0.04, size=len(y))
    ax.scatter(x, y, c=normalize_rgb(COLOR1[count]), zorder=5)
    count=count+1
    
for index, column in enumerate(new_paramsn.columns):
    mean_value = new_paramsn[column].mean()
    ax.axhline(y=mean_value, color='k', linestyle='-', linewidth=0.5, xmin=index/len(new_paramsn.columns), xmax=(index+1)/len(new_paramsn.columns))

ax.set_xticks(np.arange(len(new_paramsn.columns)))
ax.set_xticklabels(new_paramsn.columns, rotation=90)

ax.set_yticks([-1.5, 0, 1.5])

plt.savefig("U.pdf")

# %%
A0=[]
A1=[]
A2=[]
A3=[]
A4=[]
A5=[]
A6=[]
A7=[]
A8=[]
A9=[]
A10=[]
A11=[]
A12=[]
A13=[]
A15=[]
A16=[]
A17=[]
A18=[]

BBB=['x_na', 'y_na', 'g_nap', 'g_nav', 'g_unav', 'g_cav','g_kvhh', 'g_kva', 'g_kir', 'g_kvsi', 'g_kca', 'g_kna', 'g_lek', 'g_lena', 't_ca', 't_na', 'g_ampa', 'g_nmda']

S0 = pd.read_csv("ODa0.csv")
T0 = pd.read_csv("ODa10.csv")
S1 = pd.read_csv("ODa1.csv")
T1 = pd.read_csv("ODa11.csv")
S2 = pd.read_csv("ODa2.csv")
T2 = pd.read_csv("ODa12.csv")
S3 = pd.read_csv("ODa3.csv")
T3 = pd.read_csv("ODa13.csv")
S4 = pd.read_csv("ODa4.csv")
T4 = pd.read_csv("ODa14.csv")
S5 = pd.read_csv("ODa5.csv")
T5 = pd.read_csv("ODa15.csv")
S6 = pd.read_csv("ODa6.csv")
T6 = pd.read_csv("ODa16.csv")
S7 = pd.read_csv("ODa7.csv")
T7 = pd.read_csv("ODa17.csv")
S8 = pd.read_csv("ODa8.csv")
T8 = pd.read_csv("ODa18.csv")
S9 = pd.read_csv("ODa9.csv")
T9 = pd.read_csv("ODa19.csv")

S10 = pd.read_csv("OD10.csv")
T10 = pd.read_csv("OD110.csv")
S11 = pd.read_csv("OD11.csv")
T11 = pd.read_csv("OD111.csv")
S12 = pd.read_csv("OD12.csv")
T12 = pd.read_csv("OD112.csv")
S13 = pd.read_csv("OD13.csv")
T13 = pd.read_csv("OD113.csv")

S15 = pd.read_csv("OD15.csv")
T15 = pd.read_csv("OD115.csv")
S16 = pd.read_csv("OD16.csv")
T16 = pd.read_csv("OD116.csv")
S17 = pd.read_csv("OD17.csv")
T17 = pd.read_csv("OD117.csv")
S18 = pd.read_csv("OD18.csv")
T18 = pd.read_csv("OD118.csv")


# A0
for i in tqdm(range(len(S0["u1"]))):
    if i == 0:
        continue
    if (S0["u1"][i] == 0 or S0["u1"][i] == -1 or T0["u1"][i] == 0 or T0["d1"][i] == -1):
        continue
    A0.append((T0["d1"][i]) / (S0["d1"][i]))

# A1
for i in tqdm(range(len(S1["u1"]))):
    if i == 0:
        continue
    if (S1["u1"][i] == 0 or S1["u1"][i] == -1 or T1["u1"][i] == 0 or T1["d1"][i] == -1):
        continue
    A1.append((T1["d1"][i]) / (S1["d1"][i]))

# A2
for i in tqdm(range(len(S2["u1"]))):
    if i == 0:
        continue
    if (S2["u1"][i] == 0 or S2["u1"][i] == -1 or T2["u1"][i] == 0 or T2["d1"][i] == -1):
        continue
    A2.append((T2["d1"][i]) / (S2["d1"][i]))

# A3
for i in tqdm(range(len(S3["u1"]))):
    if i == 0:
        continue
    if (S3["u1"][i] == 0 or S3["u1"][i] == -1 or T3["u1"][i] == 0 or T3["d1"][i] == -1):
        continue
    A3.append((T3["d1"][i]) / (S3["d1"][i]))

# A4
for i in tqdm(range(len(S4["u1"]))):
    if i == 0:
        continue
    if (S4["u1"][i] == 0 or S4["u1"][i] == -1 or T4["u1"][i] == 0 or T4["d1"][i] == -1):
        continue
    A4.append((T4["d1"][i]) / (S4["d1"][i]))

# A5
for i in tqdm(range(len(S5["u1"]))):
    if i == 0:
        continue
    if (S5["u1"][i] == 0 or S5["u1"][i] == -1 or T5["u1"][i] == 0 or T5["d1"][i] == -1):
        continue
    A5.append((T5["d1"][i]) / (S5["d1"][i]))

# A6
for i in tqdm(range(len(S6["u1"]))):
    if i == 0:
        continue
    if (S6["u1"][i] == 0 or S6["u1"][i] == -1 or T6["u1"][i] == 0 or T6["d1"][i] == -1):
        continue
    A6.append((T6["d1"][i]) / (S6["d1"][i]))

# A7
for i in tqdm(range(len(S7["u1"]))):
    if i == 0:
        continue
    if (S7["u1"][i] == 0 or S7["u1"][i] == -1 or T7["u1"][i] == 0 or T7["d1"][i] == -1):
        continue
    A7.append((T7["d1"][i]) / (S7["d1"][i]))

# A8
for i in tqdm(range(len(S8["u1"]))):
    if i == 0:
        continue
    if (S8["u1"][i] == 0 or S8["u1"][i] == -1 or T8["u1"][i] == 0 or T8["d1"][i] == -1):
        continue
    A8.append((T8["d1"][i]) / (S8["d1"][i]))

# A9
for i in tqdm(range(len(S9["u1"]))):
    if i == 0:
        continue
    if (S9["u1"][i] == 0 or S9["u1"][i] == -1 or T9["u1"][i] == 0 or T9["d1"][i] == -1):
        continue
    A9.append((T9["d1"][i]) / (S9["d1"][i]))

# A10
for i in tqdm(range(len(S10["u1"]))):
    if i == 0:
        continue
    if (S10["u1"][i] == 0 or S10["u1"][i] == -1 or T10["u1"][i] == 0 or T10["d1"][i] == -1):
        continue
    A10.append((T10["d1"][i]) / (S10["d1"][i]))

# A11
for i in tqdm(range(len(S11["u1"]))):
    if i == 0:
        continue
    if (S11["u1"][i] == 0 or S11["u1"][i] == -1 or T11["u1"][i] == 0 or T11["d1"][i] == -1):
        continue
    A11.append((T11["d1"][i]) / (S11["d1"][i]))

# A12
for i in tqdm(range(len(S12["u1"]))):
    if i == 0:
        continue
    if (S12["u1"][i] == 0 or S12["u1"][i] == -1 or T12["u1"][i] == 0 or T12["d1"][i] == -1):
        continue
    A12.append((T12["d1"][i]) / (S12["d1"][i]))

# A13
for i in tqdm(range(len(S13["u1"]))):
    if i == 0:
        continue
    if (S13["u1"][i] == 0 or S13["u1"][i] == -1 or T13["u1"][i] == 0 or T13["d1"][i] == -1):
        continue
    A13.append((T13["d1"][i]) / (S13["d1"][i]))



# A15
for i in tqdm(range(len(S15["u1"]))):
    if i == 0:
        continue
    if (S15["u1"][i] == 0 or S15["u1"][i] == -1 or T15["u1"][i] == 0 or T15["d1"][i] == -1):
        continue
    A15.append((T15["d1"][i]) / (S15["d1"][i]))

# A16
for i in tqdm(range(len(S16["u1"]))):
    if i == 0:
        continue
    if (S16["u1"][i] == 0 or S16["u1"][i] == -1 or T16["u1"][i] == 0 or T16["d1"][i] == -1):
        continue
    A16.append((T16["d1"][i]) / (S16["d1"][i]))

# A17
for i in tqdm(range(len(S17["u1"]))):
    if i == 0:
        continue
    if (S17["u1"][i] == 0 or S17["u1"][i] == -1 or T17["u1"][i] == 0 or T17["d1"][i] == -1):
        continue
    A17.append((T17["d1"][i]) / (S17["d1"][i]))

# A18
for i in tqdm(range(len(S18["u1"]))):
    if i == 0:
        continue
    if (S18["u1"][i] == 0 or S18["u1"][i] == -1 or T18["u1"][i] == 0 or T18["d1"][i] == -1):
        continue
    A18.append((T18["d1"][i]) / (S18["d1"][i]))




    
G1=[A17,A18, A8,A2, A10,A6, A3,A4,A9,A5,A7,A11,A0,A1,A15,A16,A12,A13]
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsp=N1

fig=plt.figure(figsize=(10,10))
ax=sns.stripplot(data=new_paramsp)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            data=new_paramsp,
            showfliers=False,
            showbox=False,
            showcaps=False,
            )
# 描画

# %%
def normalize_rgb(rgb):
    return tuple(component / 255 for component in rgb)
G1=[np.log10(A17),np.log10(A18),np.log10(A8),np.log10(A2),np.log10(A6), np.log10(A10),np.log10(A3),np.log10(A4),np.log10(A9),np.log10(A5),np.log10(A7), np.log10(A11),np.log10(A0),np.log10(A1), np.log10(A15),np.log10(A16),np.log10(A12),np.log10(A13)] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsn=N1

new_paramsn = new_paramsn.select_dtypes(include=[np.number])
CC=[(202,28,29), (213,94,22), (26,47,111), (128,27,115), (245,233,40),  (0,153,68)]
COLOR1=[CC[0],CC[0],CC[0],CC[0],CC[0], CC[1],CC[2],CC[2],CC[2], CC[2], CC[2], CC[2], CC[3],CC[3], CC[4], CC[4], CC[5], CC[5]]

fig, ax = plt.subplots(figsize=(36, 9))
count=0

for index, column in enumerate(new_paramsn.columns):
    y = new_paramsn[column]
    x = np.random.normal(loc=index, scale=0.04, size=len(y))
    ax.scatter(x, y, c=normalize_rgb(COLOR1[count]), zorder=5)
    count=count+1


for index, column in enumerate(new_paramsn.columns):

    mean_value = new_paramsn[column].mean()
    ax.axhline(y=mean_value, color='k', linestyle='-', linewidth=0.5, xmin=index/len(new_paramsn.columns), xmax=(index+1)/len(new_paramsn.columns))

ax.set_xticks(np.arange(len(new_paramsn.columns)))
ax.set_xticklabels(new_paramsn.columns, rotation=90)

ax.set_yticks([-1.5, 0, 1.5])

plt.savefig("D.pdf")

# %%
def normalize_rgb(rgb):
    return tuple(component / 255 for component in rgb)
G1=[np.log10(A17),np.log10(A18),np.log10(A8),np.log10(A2),np.log10(A6), np.log10(A10),np.log10(A3),np.log10(A4),np.log10(A9),np.log10(A5),np.log10(A7), np.log10(A11),np.log10(A0),np.log10(A1), np.log10(A15),np.log10(A16),np.log10(A12),np.log10(A13)] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsn=N1


new_paramsn = new_paramsn.select_dtypes(include=[np.number])
CC=[(202,28,29), (213,94,22), (26,47,111), (128,27,115), (245,233,40),  (0,153,68)]
COLOR1=[CC[0],CC[0],CC[0],CC[0],CC[0], CC[1],CC[2],CC[2],CC[2], CC[2], CC[2], CC[2], CC[3],CC[3], CC[4], CC[4], CC[5], CC[5]]

fig, ax = plt.subplots(figsize=(16, 9))
count=0

for index, column in enumerate(new_paramsn.columns):
    y = new_paramsn[column]
    x = np.random.normal(loc=index, scale=0.04, size=len(y))
    ax.scatter(x, y, c=normalize_rgb(COLOR1[count]), zorder=5)
    count=count+1
    
for index, column in enumerate(new_paramsn.columns):
    mean_value = new_paramsn[column].mean()
    ax.axhline(y=mean_value, color='k', linestyle='-', linewidth=0.5, xmin=index/len(new_paramsn.columns), xmax=(index+1)/len(new_paramsn.columns))

ax.set_xticks(np.arange(len(new_paramsn.columns)))
ax.set_xticklabels(new_paramsn.columns, rotation=90)

ax.set_yticks([-1.5, 0, 1.5])

plt.savefig("D.pdf")

# %%
A0=[]
A1=[]
A2=[]
A3=[]
A4=[]
A5=[]
A6=[]
A7=[]
A8=[]
A9=[]
A10=[]
A11=[]
A12=[]
A13=[]
A15=[]
A16=[]
A17=[]
A18=[]

BBB=['x_na', 'y_na', 'g_nap', 'g_nav', 'g_unav', 'g_cav', 'g_kvhh', 'g_kva', 'g_kir', 'g_kvsi', 'g_kca', 'g_kna', 'g_lek', 'g_lena', 't_ca', 't_na', 'g_ampa', 'g_nmda']

S0 = pd.read_csv("ODa0.csv")
T0 = pd.read_csv("ODa10.csv")
S1 = pd.read_csv("ODa1.csv")
T1 = pd.read_csv("ODa11.csv")
S2 = pd.read_csv("ODa2.csv")
T2 = pd.read_csv("ODa12.csv")
S3 = pd.read_csv("ODa3.csv")
T3 = pd.read_csv("ODa13.csv")
S4 = pd.read_csv("ODa4.csv")
T4 = pd.read_csv("ODa14.csv")
S5 = pd.read_csv("ODa5.csv")
T5 = pd.read_csv("ODa15.csv")
S6 = pd.read_csv("ODa6.csv")
T6 = pd.read_csv("ODa16.csv")
S7 = pd.read_csv("ODa7.csv")
T7 = pd.read_csv("ODa17.csv")
S8 = pd.read_csv("ODa8.csv")
T8 = pd.read_csv("ODa18.csv")
S9 = pd.read_csv("ODa9.csv")
T9 = pd.read_csv("ODa19.csv")

S10 = pd.read_csv("OD10.csv")
T10 = pd.read_csv("OD110.csv")
S11 = pd.read_csv("OD11.csv")
T11 = pd.read_csv("OD111.csv")
S12 = pd.read_csv("OD12.csv")
T12 = pd.read_csv("OD112.csv")
S13 = pd.read_csv("OD13.csv")
T13 = pd.read_csv("OD113.csv")

S15 = pd.read_csv("OD15.csv")
T15 = pd.read_csv("OD115.csv")
S16 = pd.read_csv("OD16.csv")
T16 = pd.read_csv("OD116.csv")
S17 = pd.read_csv("OD17.csv")
T17 = pd.read_csv("OD117.csv")
S18 = pd.read_csv("OD18.csv")
T18 = pd.read_csv("OD118.csv")


# A0
for i in tqdm(range(len(S0["u1"]))):
    if i == 0:
        continue
    if (S0["u1"][i] == 0 or S0["u1"][i] == -1 or T0["u1"][i] == 0 or T0["d1"][i] == -1):
        continue
    A0.append((T0["maxna"][i] - T0["minna"][i]) / (S0["maxna"][i] - S0["minna"][i]))

# A1
for i in tqdm(range(len(S1["u1"]))):
    if i == 0:
        continue
    if (S1["u1"][i] == 0 or S1["u1"][i] == -1 or T1["u1"][i] == 0 or T1["d1"][i] == -1):
        continue
    A1.append((T1["maxna"][i] - T1["minna"][i]) / (S1["maxna"][i] - S1["minna"][i]))

# A2
for i in tqdm(range(len(S2["u1"]))):
    if i == 0:
        continue
    if (S2["u1"][i] == 0 or S2["u1"][i] == -1 or T2["u1"][i] == 0 or T2["d1"][i] == -1):
        continue
    A2.append((T2["maxna"][i] - T2["minna"][i]) / (S2["maxna"][i] - S2["minna"][i]))

# A3
for i in tqdm(range(len(S3["u1"]))):
    if i == 0:
        continue
    if (S3["u1"][i] == 0 or S3["u1"][i] == -1 or T3["u1"][i] == 0 or T3["d1"][i] == -1):
        continue
    A3.append((T3["maxna"][i] - T3["minna"][i]) / (S3["maxna"][i] - S3["minna"][i]))

# A4
for i in tqdm(range(len(S4["u1"]))):
    if i == 0:
        continue
    if (S4["u1"][i] == 0 or S4["u1"][i] == -1 or T4["u1"][i] == 0 or T4["d1"][i] == -1):
        continue
    A4.append((T4["maxna"][i] - T4["minna"][i]) / (S4["maxna"][i] - S4["minna"][i]))

# A5
for i in tqdm(range(len(S5["u1"]))):
    if i == 0:
        continue
    if (S5["u1"][i] == 0 or S5["u1"][i] == -1 or T5["u1"][i] == 0 or T5["d1"][i] == -1):
        continue
    A5.append((T5["maxna"][i] - T5["minna"][i]) / (S5["maxna"][i] - S5["minna"][i]))

# A6
for i in tqdm(range(len(S6["u1"]))):
    if i == 0:
        continue
    if (S6["u1"][i] == 0 or S6["u1"][i] == -1 or T6["u1"][i] == 0 or T6["d1"][i] == -1):
        continue
    A6.append((T6["maxna"][i] - T6["minna"][i]) / (S6["maxna"][i] - S6["minna"][i]))

# A7
for i in tqdm(range(len(S7["u1"]))):
    if i == 0:
        continue
    if (S7["u1"][i] == 0 or S7["u1"][i] == -1 or T7["u1"][i] == 0 or T7["d1"][i] == -1):
        continue
    A7.append((T7["maxna"][i] - T7["minna"][i]) / (S7["maxna"][i] - S7["minna"][i]))

# A8
for i in tqdm(range(len(S8["u1"]))):
    if i == 0:
        continue
    if (S8["u1"][i] == 0 or S8["u1"][i] == -1 or T8["u1"][i] == 0 or T8["d1"][i] == -1):
        continue
    A8.append((T8["maxna"][i] - T8["minna"][i]) / (S8["maxna"][i] - S8["minna"][i]))

# A9
for i in tqdm(range(len(S9["u1"]))):
    if i == 0:
        continue
    if (S9["u1"][i] == 0 or S9["u1"][i] == -1 or T9["u1"][i] == 0 or T9["d1"][i] == -1):
        continue
    A9.append((T9["maxna"][i] - T9["minna"][i]) / (S9["maxna"][i] - S9["minna"][i]))

# A10
for i in tqdm(range(len(S10["u1"]))):
    if i == 0:
        continue
    if (S10["u1"][i] == 0 or S10["u1"][i] == -1 or T10["u1"][i] == 0 or T10["d1"][i] == -1):
        continue
    A10.append((T10["maxna"][i] - T10["minna"][i]) / (S10["maxna"][i] - S10["minna"][i]))

# A11
for i in tqdm(range(len(S11["u1"]))):
    if i == 0:
        continue
    if (S11["u1"][i] == 0 or S11["u1"][i] == -1 or T11["u1"][i] == 0 or T11["d1"][i] == -1):
        continue
    A11.append((T11["maxna"][i] - T11["minna"][i]) / (S11["maxna"][i] - S11["minna"][i]))

# A12
for i in tqdm(range(len(S12["u1"]))):
    if i == 0:
        continue
    if (S12["u1"][i] == 0 or S12["u1"][i] == -1 or T12["u1"][i] == 0 or T12["d1"][i] == -1):
        continue
    A12.append((T12["maxna"][i] - T12["minna"][i]) / (S12["maxna"][i] - S12["minna"][i]))

# A13
for i in tqdm(range(len(S13["u1"]))):
    if i == 0:
        continue
    if (S13["u1"][i] == 0 or S13["u1"][i] == -1 or T13["u1"][i] == 0 or T13["d1"][i] == -1):
        continue
    A13.append((T13["maxna"][i] - T13["minna"][i]) / (S13["maxna"][i] - S13["minna"][i]))



# A15
for i in tqdm(range(len(S15["u1"]))):
    if i == 0:
        continue
    if (S15["u1"][i] == 0 or S15["u1"][i] == -1 or T15["u1"][i] == 0 or T15["d1"][i] == -1):
        continue
    A15.append((T15["maxna"][i] - T15["minna"][i]) / (S15["maxna"][i] - S15["minna"][i]))

# A16
for i in tqdm(range(len(S16["u1"]))):
    if i == 0:
        continue
    if (S16["u1"][i] == 0 or S16["u1"][i] == -1 or T16["u1"][i] == 0 or T16["d1"][i] == -1):
        continue
    A16.append((T16["maxna"][i] - T16["minna"][i]) / (S16["maxna"][i] - S16["minna"][i]))

# A17
for i in tqdm(range(len(S17["u1"]))):
    if i == 0:
        continue
    if (S17["u1"][i] == 0 or S17["u1"][i] == -1 or T17["u1"][i] == 0 or T17["d1"][i] == -1):
        continue
    A17.append((T17["maxna"][i] - T17["minna"][i]) / (S17["maxna"][i] - S17["minna"][i]))

# A18
for i in tqdm(range(len(S18["u1"]))):
    if i == 0:
        continue
    if (S18["u1"][i] == 0 or S18["u1"][i] == -1 or T18["u1"][i] == 0 or T18["d1"][i] == -1):
        continue
    A18.append((T18["maxna"][i] - T18["minna"][i]) / (S18["maxna"][i] - S18["minna"][i]))




    
G1=[A17,A18, A8,A2, A10,A6, A3,A4,A9,A5,A7,A11,A0,A1,A15,A16,A12,A13]
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsp=N1

fig=plt.figure(figsize=(10,10))
ax=sns.stripplot(data=new_paramsp)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            data=new_paramsp,
            showfliers=False,
            showbox=False,
            showcaps=False,
            )

# %%
def normalize_rgb(rgb):
    return tuple(component / 255 for component in rgb)
G1=[np.log10(A17),np.log10(A18),np.log10(A8),np.log10(A2),np.log10(A6), np.log10(A10),np.log10(A3),np.log10(A4),np.log10(A9),np.log10(A5),np.log10(A7), np.log10(A11),np.log10(A0),np.log10(A1), np.log10(A15),np.log10(A16),np.log10(A12),np.log10(A13)] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsn=N1


new_paramsn = new_paramsn.select_dtypes(include=[np.number])
CC=[(202,28,29), (213,94,22), (26,47,111), (128,27,115), (245,233,40),  (0,153,68)]
COLOR1=[CC[0],CC[0],CC[0],CC[0],CC[0], CC[1],CC[2],CC[2],CC[2], CC[2], CC[2], CC[2], CC[3],CC[3], CC[4], CC[4], CC[5], CC[5]]

fig, ax = plt.subplots(figsize=(36, 9))
count=0

for index, column in enumerate(new_paramsn.columns):
    y = new_paramsn[column]
    x = np.random.normal(loc=index, scale=0.04, size=len(y))
    ax.scatter(x, y, c=normalize_rgb(COLOR1[count]), zorder=5)
    count=count+1

for index, column in enumerate(new_paramsn.columns):
    mean_value = new_paramsn[column].mean()
    ax.axhline(y=mean_value, color='k', linestyle='-', linewidth=0.5, xmin=index/len(new_paramsn.columns), xmax=(index+1)/len(new_paramsn.columns))


ax.set_xticks(np.arange(len(new_paramsn.columns)))
ax.set_xticklabels(new_paramsn.columns, rotation=90)

ax.set_yticks([-1.5, 0, 1.5])

plt.savefig("ON.pdf")

# %%
A0=[]
A1=[]
A2=[]
A3=[]
A4=[]
A5=[]
A6=[]
A7=[]
A8=[]
A9=[]
A10=[]
A11=[]
A12=[]
A13=[]
A15=[]
A16=[]
A17=[]
A18=[]

BBB=['x_na', 'y_na', 'g_nap', 'g_nav', 'g_unav','g_cav', 'g_kvhh', 'g_kva', 'g_kir', 'g_kvsi', 'g_kca', 'g_kna', 'g_lek', 'g_lena', 't_ca', 't_na', 'g_ampa', 'g_nmda']

S0 = pd.read_csv("ODa0.csv")
T0 = pd.read_csv("ODa10.csv")
S1 = pd.read_csv("ODa1.csv")
T1 = pd.read_csv("ODa11.csv")
S2 = pd.read_csv("ODa2.csv")
T2 = pd.read_csv("ODa12.csv")
S3 = pd.read_csv("ODa3.csv")
T3 = pd.read_csv("ODa13.csv")
S4 = pd.read_csv("ODa4.csv")
T4 = pd.read_csv("ODa14.csv")
S5 = pd.read_csv("ODa5.csv")
T5 = pd.read_csv("ODa15.csv")
S6 = pd.read_csv("ODa6.csv")
T6 = pd.read_csv("ODa16.csv")
S7 = pd.read_csv("ODa7.csv")
T7 = pd.read_csv("ODa17.csv")
S8 = pd.read_csv("ODa8.csv")
T8 = pd.read_csv("ODa18.csv")
S9 = pd.read_csv("ODa9.csv")
T9 = pd.read_csv("ODa19.csv")

S10 = pd.read_csv("OD10.csv")
T10 = pd.read_csv("OD110.csv")
S11 = pd.read_csv("OD11.csv")
T11 = pd.read_csv("OD111.csv")
S12 = pd.read_csv("OD12.csv")
T12 = pd.read_csv("OD112.csv")
S13 = pd.read_csv("OD13.csv")
T13 = pd.read_csv("OD113.csv")

S15 = pd.read_csv("OD15.csv")
T15 = pd.read_csv("OD115.csv")
S16 = pd.read_csv("OD16.csv")
T16 = pd.read_csv("OD116.csv")
S17 = pd.read_csv("OD17.csv")
T17 = pd.read_csv("OD117.csv")
S18 = pd.read_csv("OD18.csv")
T18 = pd.read_csv("OD118.csv")


# A0
for i in tqdm(range(len(S0["u1"]))):
    if i == 0:
        continue
    if (S0["u1"][i] == 0 or S0["u1"][i] == -1 or T0["u1"][i] == 0 or T0["d1"][i] == -1):
        continue
    A0.append((T0["maxca"][i] - T0["minca"][i]) / (S0["maxca"][i] - S0["minca"][i]))

# A1
for i in tqdm(range(len(S1["u1"]))):
    if i == 0:
        continue
    if (S1["u1"][i] == 0 or S1["u1"][i] == -1 or T1["u1"][i] == 0 or T1["d1"][i] == -1):
        continue
    A1.append((T1["maxca"][i] - T1["minca"][i]) / (S1["maxca"][i] - S1["minca"][i]))

# A2
for i in tqdm(range(len(S2["u1"]))):
    if i == 0:
        continue
    if (S2["u1"][i] == 0 or S2["u1"][i] == -1 or T2["u1"][i] == 0 or T2["d1"][i] == -1):
        continue
    A2.append((T2["maxca"][i] - T2["minca"][i]) / (S2["maxca"][i] - S2["minca"][i]))

# A3
for i in tqdm(range(len(S3["u1"]))):
    if i == 0:
        continue
    if (S3["u1"][i] == 0 or S3["u1"][i] == -1 or T3["u1"][i] == 0 or T3["d1"][i] == -1):
        continue
    A3.append((T3["maxca"][i] - T3["minca"][i]) / (S3["maxca"][i] - S3["minca"][i]))

# A4
for i in tqdm(range(len(S4["u1"]))):
    if i == 0:
        continue
    if (S4["u1"][i] == 0 or S4["u1"][i] == -1 or T4["u1"][i] == 0 or T4["d1"][i] == -1):
        continue
    A4.append((T4["maxca"][i] - T4["minca"][i]) / (S4["maxca"][i] - S4["minca"][i]))

# A5
for i in tqdm(range(len(S5["u1"]))):
    if i == 0:
        continue
    if (S5["u1"][i] == 0 or S5["u1"][i] == -1 or T5["u1"][i] == 0 or T5["d1"][i] == -1):
        continue
    A5.append((T5["maxca"][i] - T5["minca"][i]) / (S5["maxca"][i] - S5["minca"][i]))

# A6
for i in tqdm(range(len(S6["u1"]))):
    if i == 0:
        continue
    if (S6["u1"][i] == 0 or S6["u1"][i] == -1 or T6["u1"][i] == 0 or T6["d1"][i] == -1):
        continue
    A6.append((T6["maxca"][i] - T6["minca"][i]) / (S6["maxca"][i] - S6["minca"][i]))

# A7
for i in tqdm(range(len(S7["u1"]))):
    if i == 0:
        continue
    if (S7["u1"][i] == 0 or S7["u1"][i] == -1 or T7["u1"][i] == 0 or T7["d1"][i] == -1):
        continue
    A7.append((T7["maxca"][i] - T7["minca"][i]) / (S7["maxca"][i] - S7["minca"][i]))

# A8
for i in tqdm(range(len(S8["u1"]))):
    if i == 0:
        continue
    if (S8["u1"][i] == 0 or S8["u1"][i] == -1 or T8["u1"][i] == 0 or T8["d1"][i] == -1):
        continue
    A8.append((T8["maxca"][i] - T8["minca"][i]) / (S8["maxca"][i] - S8["minca"][i]))

# A9
for i in tqdm(range(len(S9["u1"]))):
    if i == 0:
        continue
    if (S9["u1"][i] == 0 or S9["u1"][i] == -1 or T9["u1"][i] == 0 or T9["d1"][i] == -1):
        continue
    A9.append((T9["maxca"][i] - T9["minca"][i]) / (S9["maxca"][i] - S9["minca"][i]))

# A10
for i in tqdm(range(len(S10["u1"]))):
    if i == 0:
        continue
    if (S10["u1"][i] == 0 or S10["u1"][i] == -1 or T10["u1"][i] == 0 or T10["d1"][i] == -1):
        continue
    A10.append((T10["maxca"][i] - T10["minca"][i]) / (S10["maxca"][i] - S10["minca"][i]))

# A11
for i in tqdm(range(len(S11["u1"]))):
    if i == 0:
        continue
    if (S11["u1"][i] == 0 or S11["u1"][i] == -1 or T11["u1"][i] == 0 or T11["d1"][i] == -1):
        continue
    A11.append((T11["maxca"][i] - T11["minca"][i]) / (S11["maxca"][i] - S11["minca"][i]))

# A12
for i in tqdm(range(len(S12["u1"]))):
    if i == 0:
        continue
    if (S12["u1"][i] == 0 or S12["u1"][i] == -1 or T12["u1"][i] == 0 or T12["d1"][i] == -1):
        continue
    A12.append((T12["maxca"][i] - T12["minca"][i]) / (S12["maxca"][i] - S12["minca"][i]))

# A13
for i in tqdm(range(len(S13["u1"]))):
    if i == 0:
        continue
    if (S13["u1"][i] == 0 or S13["u1"][i] == -1 or T13["u1"][i] == 0 or T13["d1"][i] == -1):
        continue
    A13.append((T13["maxca"][i] - T13["minca"][i]) / (S13["maxca"][i] - S13["minca"][i]))



# A15
for i in tqdm(range(len(S15["u1"]))):
    if i == 0:
        continue
    if (S15["u1"][i] == 0 or S15["u1"][i] == -1 or T15["u1"][i] == 0 or T15["d1"][i] == -1):
        continue
    A15.append((T15["maxca"][i] - T15["minca"][i]) / (S15["maxca"][i] - S15["minca"][i]))

# A16
for i in tqdm(range(len(S16["u1"]))):
    if i == 0:
        continue
    if (S16["u1"][i] == 0 or S16["u1"][i] == -1 or T16["u1"][i] == 0 or T16["d1"][i] == -1):
        continue
    A16.append((T16["maxca"][i] - T16["minca"][i]) / (S16["maxca"][i] - S16["minca"][i]))

# A17
for i in tqdm(range(len(S17["u1"]))):
    if i == 0:
        continue
    if (S17["u1"][i] == 0 or S17["u1"][i] == -1 or T17["u1"][i] == 0 or T17["d1"][i] == -1):
        continue
    A17.append((T17["maxca"][i] - T17["minca"][i]) / (S17["maxca"][i] - S17["minca"][i]))

# A18
for i in tqdm(range(len(S18["u1"]))):
    if i == 0:
        continue
    if (S18["u1"][i] == 0 or S18["u1"][i] == -1 or T18["u1"][i] == 0 or T18["d1"][i] == -1):
        continue
    A18.append((T18["maxca"][i] - T18["minca"][i]) / (S18["maxca"][i] - S18["minca"][i]))





    
G1=[A17,A18, A8,A2, A10,A6, A3,A4,A9,A5,A7,A11,A0,A1,A15,A16,A12,A13]
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsp=N1

fig=plt.figure(figsize=(10,10))
ax=sns.stripplot(data=new_paramsp)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            data=new_paramsp,
            showfliers=False,
            showbox=False,
            showcaps=False,
            )

# %%
def normalize_rgb(rgb):
    return tuple(component / 255 for component in rgb)
G1=[np.log10(A17),np.log10(A18),np.log10(A8),np.log10(A2),np.log10(A6), np.log10(A10),np.log10(A3),np.log10(A4),np.log10(A9),np.log10(A5),np.log10(A7), np.log10(A11),np.log10(A0),np.log10(A1), np.log10(A15),np.log10(A16),np.log10(A12),np.log10(A13)] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsn=N1


new_paramsn = new_paramsn.select_dtypes(include=[np.number])
CC=[(202,28,29), (213,94,22), (26,47,111), (128,27,115), (245,233,40),  (0,153,68)]
COLOR1=[CC[0],CC[0],CC[0],CC[0],CC[0], CC[1],CC[2],CC[2],CC[2], CC[2], CC[2], CC[2], CC[3],CC[3], CC[4], CC[4], CC[5], CC[5]]

fig, ax = plt.subplots(figsize=(36, 9))
count=0

for index, column in enumerate(new_paramsn.columns):
    y = new_paramsn[column]
    x = np.random.normal(loc=index, scale=0.04, size=len(y))
    ax.scatter(x, y, c=normalize_rgb(COLOR1[count]), zorder=5)
    count=count+1

for index, column in enumerate(new_paramsn.columns):
    mean_value = new_paramsn[column].mean()
    ax.axhline(y=mean_value, color='k', linestyle='-', linewidth=0.5, xmin=index/len(new_paramsn.columns), xmax=(index+1)/len(new_paramsn.columns))

ax.set_xticks(np.arange(len(new_paramsn.columns)))
ax.set_xticklabels(new_paramsn.columns, rotation=90)

ax.set_yticks([-1.5, 0, 1.5])

plt.savefig("OC.pdf")

# %%
A0=[]
A1=[]
A2=[]
A3=[]
A4=[]
A5=[]
A6=[]
A7=[]
A8=[]
A9=[]
A10=[]
A11=[]
A12=[]
A13=[]
A15=[]
A16=[]
A17=[]
A18=[]

BBB=['x_na', 'y_na', 'g_nap', 'g_nav', 'g_unav','g_cav', 'g_kvhh', 'g_kva', 'g_kir', 'g_kvsi', 'g_kca', 'g_kna', 'g_lek', 'g_lena', 't_ca', 't_na', 'g_ampa', 'g_nmda']

S0 = pd.read_csv("ODa0.csv")
T0 = pd.read_csv("ODa10.csv")
S1 = pd.read_csv("ODa1.csv")
T1 = pd.read_csv("ODa11.csv")
S2 = pd.read_csv("ODa2.csv")
T2 = pd.read_csv("ODa12.csv")
S3 = pd.read_csv("ODa3.csv")
T3 = pd.read_csv("ODa13.csv")
S4 = pd.read_csv("ODa4.csv")
T4 = pd.read_csv("ODa14.csv")
S5 = pd.read_csv("ODa5.csv")
T5 = pd.read_csv("ODa15.csv")
S6 = pd.read_csv("ODa6.csv")
T6 = pd.read_csv("ODa16.csv")
S7 = pd.read_csv("ODa7.csv")
T7 = pd.read_csv("ODa17.csv")
S8 = pd.read_csv("ODa8.csv")
T8 = pd.read_csv("ODa18.csv")
S9 = pd.read_csv("ODa9.csv")
T9 = pd.read_csv("ODa19.csv")

S10 = pd.read_csv("OD10.csv")
T10 = pd.read_csv("OD110.csv")
S11 = pd.read_csv("OD11.csv")
T11 = pd.read_csv("OD111.csv")
S12 = pd.read_csv("OD12.csv")
T12 = pd.read_csv("OD112.csv")
S13 = pd.read_csv("OD13.csv")
T13 = pd.read_csv("OD113.csv")

S15 = pd.read_csv("OD15.csv")
T15 = pd.read_csv("OD115.csv")
S16 = pd.read_csv("OD16.csv")
T16 = pd.read_csv("OD116.csv")
S17 = pd.read_csv("OD17.csv")
T17 = pd.read_csv("OD117.csv")
S18 = pd.read_csv("OD18.csv")
T18 = pd.read_csv("OD118.csv")

# A0
for i in tqdm(range(len(S0["u1"]))):
    if i == 0:
        continue
    if (S0["u1"][i] == 0 or S0["u1"][i] == -1 or T0["u1"][i] == 0 or T0["d1"][i] == -1):
        continue
    A0.append((T0["mean"][i]) / (S0["mean"][i]))

# A1
for i in tqdm(range(len(S1["u1"]))):
    if i == 0:
        continue
    if (S1["u1"][i] == 0 or S1["u1"][i] == -1 or T1["u1"][i] == 0 or T1["d1"][i] == -1):
        continue
    A1.append((T1["mean"][i]) / (S1["mean"][i]))

# A2
for i in tqdm(range(len(S2["u1"]))):
    if i == 0:
        continue
    if (S2["u1"][i] == 0 or S2["u1"][i] == -1 or T2["u1"][i] == 0 or T2["d1"][i] == -1):
        continue
    A2.append((T2["mean"][i]) / (S2["mean"][i]))

# A3
for i in tqdm(range(len(S3["u1"]))):
    if i == 0:
        continue
    if (S3["u1"][i] == 0 or S3["u1"][i] == -1 or T3["u1"][i] == 0 or T3["d1"][i] == -1):
        continue
    A3.append((T3["mean"][i]) / (S3["mean"][i]))

# A4
for i in tqdm(range(len(S4["u1"]))):
    if i == 0:
        continue
    if (S4["u1"][i] == 0 or S4["u1"][i] == -1 or T4["u1"][i] == 0 or T4["d1"][i] == -1):
        continue
    A4.append((T4["mean"][i]) / (S4["mean"][i]))

# A5
for i in tqdm(range(len(S5["u1"]))):
    if i == 0:
        continue
    if (S5["u1"][i] == 0 or S5["u1"][i] == -1 or T5["u1"][i] == 0 or T5["d1"][i] == -1):
        continue
    A5.append((T5["mean"][i]) / (S5["mean"][i]))

# A6
for i in tqdm(range(len(S6["u1"]))):
    if i == 0:
        continue
    if (S6["u1"][i] == 0 or S6["u1"][i] == -1 or T6["u1"][i] == 0 or T6["d1"][i] == -1):
        continue
    A6.append((T6["mean"][i]) / (S6["mean"][i]))

# A7
for i in tqdm(range(len(S7["u1"]))):
    if i == 0:
        continue
    if (S7["u1"][i] == 0 or S7["u1"][i] == -1 or T7["u1"][i] == 0 or T7["d1"][i] == -1):
        continue
    A7.append((T7["mean"][i]) / (S7["mean"][i]))

# A8
for i in tqdm(range(len(S8["u1"]))):
    if i == 0:
        continue
    if (S8["u1"][i] == 0 or S8["u1"][i] == -1 or T8["u1"][i] == 0 or T8["d1"][i] == -1):
        continue
    A8.append((T8["mean"][i]) / (S8["mean"][i]))

# A9
for i in tqdm(range(len(S9["u1"]))):
    if i == 0:
        continue
    if (S9["u1"][i] == 0 or S9["u1"][i] == -1 or T9["u1"][i] == 0 or T9["d1"][i] == -1):
        continue
    A9.append((T9["mean"][i]) / (S9["mean"][i]))

# A10
for i in tqdm(range(len(S10["u1"]))):
    if i == 0:
        continue
    if (S10["u1"][i] == 0 or S10["u1"][i] == -1 or T10["u1"][i] == 0 or T10["d1"][i] == -1):
        continue
    A10.append((T10["mean"][i]) / (S10["mean"][i]))

# A11
for i in tqdm(range(len(S11["u1"]))):
    if i == 0:
        continue
    if (S11["u1"][i] == 0 or S11["u1"][i] == -1 or T11["u1"][i] == 0 or T11["d1"][i] == -1):
        continue
    A11.append((T11["mean"][i]) / (S11["mean"][i]))

# A12
for i in tqdm(range(len(S12["u1"]))):
    if i == 0:
        continue
    if (S12["u1"][i] == 0 or S12["u1"][i] == -1 or T12["u1"][i] == 0 or T12["d1"][i] == -1):
        continue
    A12.append((T12["mean"][i]) / (S12["mean"][i]))

# A13
for i in tqdm(range(len(S13["u1"]))):
    if i == 0:
        continue
    if (S13["u1"][i] == 0 or S13["u1"][i] == -1 or T13["u1"][i] == 0 or T13["d1"][i] == -1):
        continue
    A13.append((T13["mean"][i]) / (S13["mean"][i]))



# A15
for i in tqdm(range(len(S15["u1"]))):
    if i == 0:
        continue
    if (S15["u1"][i] == 0 or S15["u1"][i] == -1 or T15["u1"][i] == 0 or T15["d1"][i] == -1):
        continue
    A15.append((T15["mean"][i]) / (S15["mean"][i]))

# A16
for i in tqdm(range(len(S16["u1"]))):
    if i == 0:
        continue
    if (S16["u1"][i] == 0 or S16["u1"][i] == -1 or T16["u1"][i] == 0 or T16["d1"][i] == -1):
        continue
    A16.append((T16["mean"][i]) / (S16["mean"][i]))

# A17
for i in tqdm(range(len(S17["u1"]))):
    if i == 0:
        continue
    if (S17["u1"][i] == 0 or S17["u1"][i] == -1 or T17["u1"][i] == 0 or T17["d1"][i] == -1):
        continue
    A17.append((T17["mean"][i]) / (S17["mean"][i]))

# A18
for i in tqdm(range(len(S18["u1"]))):
    if i == 0:
        continue
    if (S18["u1"][i] == 0 or S18["u1"][i] == -1 or T18["u1"][i] == 0 or T18["d1"][i] == -1):
        continue
    A18.append((T18["mean"][i]) / (S18["mean"][i]))




G1=[A17,A18, A8,A2, A10,A6, A3,A4,A9,A5,A7,A11,A0,A1,A15,A16,A12,A13]
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsp=N1

fig=plt.figure(figsize=(10,10))
ax=sns.stripplot(data=new_paramsp)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            data=new_paramsp,
            showfliers=False,
            showbox=False,
            showcaps=False,
            )

# %%
def normalize_rgb(rgb):
    return tuple(component / 255 for component in rgb)
G1=[np.log10(A17),np.log10(A18),np.log10(A8),np.log10(A2),np.log10(A6), np.log10(A10),np.log10(A3),np.log10(A4),np.log10(A9),np.log10(A5),np.log10(A7), np.log10(A11),np.log10(A0),np.log10(A1), np.log10(A15),np.log10(A16),np.log10(A12),np.log10(A13)] 
    
dic1={key:  val for key, val in zip(BBB,G1)}
new_params1=dic1
TTp=new_params1
N1: pd.DataFrame=pd.DataFrame.from_dict(new_params1, orient="index").T
new_paramsn=N1

new_paramsn = new_paramsn.select_dtypes(include=[np.number])
CC=[(202,28,29), (213,94,22), (26,47,111), (128,27,115), (245,233,40),  (0,153,68)]
COLOR1=[CC[0],CC[0],CC[0],CC[0],CC[0], CC[1],CC[2],CC[2],CC[2], CC[2], CC[2], CC[2], CC[3],CC[3], CC[4], CC[4], CC[5], CC[5]]

fig, ax = plt.subplots(figsize=(36, 9))
count=0

for index, column in enumerate(new_paramsn.columns):
    y = new_paramsn[column]
    x = np.random.normal(loc=index, scale=0.04, size=len(y))
    ax.scatter(x, y, c=normalize_rgb(COLOR1[count]), zorder=5)
    count=count+1
    
for index, column in enumerate(new_paramsn.columns):
    mean_value = new_paramsn[column].mean()
    ax.axhline(y=mean_value, color='k', linestyle='-', linewidth=0.5, xmin=index/len(new_paramsn.columns), xmax=(index+1)/len(new_paramsn.columns))

ax.set_xticks(np.arange(len(new_paramsn.columns)))
ax.set_xticklabels(new_paramsn.columns, rotation=90)

ax.set_yticks([-1.5, 0, 1.5])

plt.savefig("I.pdf")
