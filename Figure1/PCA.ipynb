# %%
import pandas as pd
import numpy as np
import statistics 
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
from tqdm import tqdm

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
plt.rcParams['font.family'] = 'Arial'

# %%
#A.csv contains parameter sets for a particular model. Appropriate CSV has to be extracted from CSV file.
A=pd.read_csv("A.csv")
A.head(20)

# %%
x=len(A["g_kvhh"])
#Number must be 7 for NAN model, 8 for NAN model with Na+/K+ ATPase, 19 for FNAN model.
Number=8

B=np.zeros((x-1,Number))
if(Number==7):
    b0=[]
    b1=[]
    b2=[]
    b3=[]
    b4=[]
    b5=[]
    b6=[]

    for i in tqdm(range(x)):
        if(i==0):
            continue
        b0.append(A["g_kvhh"][i])
        b1.append(A["g_unav"][i])
        b2.append(A["g_nak"][i])
        b3.append(A["g_leak"][i])
        b4.append(A["g_cav"][i])
        b5.append(A["x_na"][i])
        b6.append(A["y_na"][i])

    for i in range(x-1):
        B[i][0]=(b0[i]-statistics.mean(b0))/statistics.stdev(b0)
        B[i][1]=(b0[i]-statistics.mean(b0))/statistics.stdev(b0)
        B[i][2]=(b0[i]-statistics.mean(b0))/statistics.stdev(b0)
        B[i][3]=(b0[i]-statistics.mean(b0))/statistics.stdev(b0)
        B[i][4]=(b0[i]-statistics.mean(b0))/statistics.stdev(b0)
        B[i][5]=(b0[i]-statistics.mean(b0))/statistics.stdev(b0)
        B[i][6]=(b0[i]-statistics.mean(b0))/statistics.stdev(b0)

        
if(Number==8):
    b0=[]
    b1=[]
    b2=[]
    b3=[]
    b4=[]
    b5=[]
    b6=[]
    b7=[]

    for i in tqdm(range(x)):
        if(i==0):
            continue
        b0.append(A["g_kvhh"][i])
        b1.append(A["g_unav"][i])
        b2.append(A["g_kna"][i])
        b3.append(A["g_leak"][i])
        b4.append(A["g_cav"][i])
        b5.append(A["t_na"][i])
        b6.append(A["x_na"][i])
        b7.append(A["y_na"][i])

    for i in range(x-1):
        B[i][0] = (b0[i] - 0) / statistics.stdev(b0)
        B[i][1] = (b1[i] - 0) / statistics.stdev(b1)
        B[i][2] = (b2[i] - 0) / statistics.stdev(b2)
        B[i][3] = (b3[i] - 0) / statistics.stdev(b3)
        B[i][4] = (b4[i] - 0) / statistics.stdev(b4)
        B[i][5] = (b5[i] - 0) / statistics.stdev(b5)
        B[i][6] = (b6[i] - 0) / statistics.stdev(b6)
        B[i][7] = (b7[i] - 0) / statistics.stdev(b7)
    
if(Number==18):
    b0=[]
    b1=[]
    b2=[]
    b3=[]
    b4=[]
    b5=[]
    b6=[]
    b7=[]
    b8=[]
    b9=[]
    b10=[]
    b11=[]
    b12=[]
    b13=[]
    b14=[]
    b15=[]
    b16=[]
    b17=[]

    for i in tqdm(range(x)):
        if(i==0):
            continue
        b0.append(S['g_leak'][i])
        b1.append(S['g_nav'][i])
        b2.append(S['g_kvhh'][i])
        b3.append(S['g_kva'][i])
        b4.append(S['g_kvsi'][i])
        b5.append(S['g_cav'][i])
        b6.append(S['g_kca'][i])
        b7.append(S['g_nap'][i])
        b8.append(S['g_kir'][i])
        b9.append(S['g_unav'][i])
        b10.append(S['g_kna'][i])
        b11.append(S['g_ampar'][i])
        b12.append(S['g_nmdar'][i])
        b13.append(S['g_gabar'][i])
        b14.append(S['t_ca'][i])
        b15.append(S['t_na'][i])
        b16.append(S['x_na'][i])
        b17.append(S['y_na'][i])


    for i in range(x-1):
        B[i][0] = (b0[i] - 0) / statistics.stdev(b0)
        B[i][1] = (b1[i] - 0) / statistics.stdev(b1)
        B[i][2] = (b2[i] - 0) / statistics.stdev(b2)
        B[i][3] = (b3[i] - 0) / statistics.stdev(b3)
        B[i][4] = (b4[i] - 0) / statistics.stdev(b4)
        B[i][5] = (b5[i] - 0) / statistics.stdev(b5)
        B[i][6] = (b6[i] - 0) / statistics.stdev(b6)
        B[i][7] = (b7[i] - 0) / statistics.stdev(b7)
        B[i][8] = (b8[i] - 0) / statistics.stdev(b8)
        B[i][9] = (b9[i] - 0) / statistics.stdev(b9)
        B[i][10] = (b10[i] - 0) / statistics.stdev(b10)
        B[i][11] = (b11[i] - 0) / statistics.stdev(b11)
        B[i][12] = (b12[i] - 0) / statistics.stdev(b12)
        B[i][13] = (b13[i] - 0) / statistics.stdev(b13)
        B[i][14] = (b14[i] - 0) / statistics.stdev(b14)
        B[i][15] = (b15[i] - 0) / statistics.stdev(b15)
        B[i][16] = (b16[i] - 0) / statistics.stdev(b16)
        B[i][17] = (b17[i] - 0) / statistics.stdev(b17)




#PCA analysis
pca.fit(B)
feature=pca.transform(B)
x=[]
y=[]
for i in range(len(feature)):
    x.append(feature[i][0])
    y.append(feature[i][1])

#plt.figure(figsize=(10,10))
plt.scatter(x,y)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.savefig("Kernel.pdf")

# %%
from scipy.stats import gaussian_kde
kde=gaussian_kde(feature.T)
x1=np.linspace(-5,8,500)
y1=np.linspace(-3,5,500)
xxx,yyy=np.meshgrid(x1,y1)
meshdata=np.vstack([xxx.ravel(), yyy.ravel()])

z=kde.evaluate(meshdata)


fig=plt.figure(facecolor="w")
ax=fig.add_subplot(111, title="MDKDE")
ax.scatter(feature[:,0], feature[:,1], c="b")
ax.contourf(xxx,yyy,z.reshape(len(x1),len(y1)), cmap="Blues", alpha=0.5)
plt.show()

# %%
cmax=max(z)
Z=z.reshape(500,500)
X=-100
Y=-100
A=-100
B=-100
Diff=1000000
for i in range(500):
    for j in range(500):
        dif=(cmax-Z[i][j])**2
        if(dif<=Diff):
            Diff=dif
            X=x1[i]
            Y=y1[j]
            A=i
            B=j

# %%
memo=-100
M=1000000
a=[]
psps1=[]

for i in range(len(feature)):
    m=(X-feature[i][0])**2+(Y-feature[i][1])**2
    psps1.append(m)
    if(m<=M):
        M=m
        memo=i
        a.append(memo)
    if(i==453):
        print(m)
print(memo)

# %%
FUMO=[]
for i in range(len(feature)):
    m=(X-feature[i][0])**2+(Y-feature[i][1])**2
    FUMO.append([m,i])

# %%
FUMO.sort()
#FUMO contains the representative parameter set. One representative set was chosen among FUMO[0][1]~FUMO[0][99].
