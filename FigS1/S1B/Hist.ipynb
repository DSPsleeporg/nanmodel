# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
plt.rcParams['font.family'] = 'Arial'

# %%
S=pd.read_csv("A.csv")

# %%
x=[]
for i in range(len(S["g_kvhh"])):
    if i==0:
        continue
    ss1=S["g_kna"][i]
    x.append(ss1)
    
fig=plt.figure()
ax = fig.add_subplot(111)
Z=np.linspace(-2,2,3)


y=[]
for i in range(len(x)):
    y.append(np.log10(x[i]))
plt.hist(y,bins=40)
plt.yticks(np.arange(0, 150, 50))
ax.set_xticks(Z)
plt.title("g_kna")

plt.savefig("SupFig1Bkna.pdf")

# %%
x=[]
for i in range(len(S["g_kvhh"])):
    if i==0:
        continue
    ss1=S["g_kvhh"][i]
    x.append(ss1)
    
fig=plt.figure()
ax = fig.add_subplot(111)
Z=np.linspace(-2,2,3)


y=[]
for i in range(len(x)):
    y.append(np.log10(x[i]))
plt.hist(y,bins=40)
plt.yticks(np.arange(0, 150, 50))
ax.set_xticks(Z)
plt.title("g_kvhh")

plt.savefig("SupFig1Bkvhh.pdf")

# %%
x=[]
for i in range(len(S["g_kvhh"])):
    if i==0:
        continue
    ss1=S["g_unav"][i]
    x.append(ss1)
    
fig=plt.figure()
ax = fig.add_subplot(111)
Z=np.linspace(-2,2,3)


y=[]
for i in range(len(x)):
    y.append(np.log10(x[i]))
plt.hist(y,bins=40)
plt.yticks(np.arange(0, 150, 50))
ax.set_xticks(Z)
plt.title("g_uunav")

plt.savefig("SupFig1Bunav.pdf")

# %%
x=[]
for i in range(len(S["g_kvhh"])):
    if i==0:
        continue
    ss1=S["g_leak"][i]
    x.append(ss1)
    
fig=plt.figure()
ax = fig.add_subplot(111)
Z=np.linspace(-2,2,3)


y=[]
for i in range(len(x)):
    y.append(np.log10(x[i]))
plt.hist(y,bins=40)
plt.yticks(np.arange(0, 150, 50))
ax.set_xticks(Z)
plt.title("g_leak")

plt.savefig("SupFig1Bleak.pdf")

# %%
x=[]
for i in range(len(S["g_kvhh"])):
    if i==0:
        continue
    ss1=S["g_cav"][i]
    x.append(ss1)
    
fig=plt.figure()
ax = fig.add_subplot(111)
Z=np.linspace(-2,2,3)


y=[]
for i in range(len(x)):
    y.append(np.log10(x[i]))
plt.hist(y,bins=40)
plt.yticks(np.arange(0, 150, 50))
ax.set_xticks(Z)
plt.title("g_cav")

plt.savefig("SupFig1Bcav.pdf")

# %%
x=[]
for i in range(len(S["g_kvhh"])):
    if i==0:
        continue
    ss1=S["x_na"][i]

    x.append(ss1)

plt.hist(x,bins=40,range=(-45,45))
plt.yticks(np.arange(0, 150, 50))
plt.title("x_na")
plt.savefig("SupFig1Bxna.pdf")

# %%
x=[]
for i in range(len(S["g_kvhh"])):
    if i==0:
        continue
    ss1=S["y_na"][i]

    x.append(ss1)

plt.hist(x,bins=40,range=(-45,45))
plt.yticks(np.arange(0, 150, 50))
plt.title("y_na")
plt.savefig("SupFig1Byna.pdf")

# %%
x=[]
for i in range(len(S["g_kvhh"])):
    if i==0:
        continue
    ss1=S["t_na"][i]
    x.append(ss1)
    
fig=plt.figure()
ax = fig.add_subplot(111)
Z=np.linspace(3,4,3)


y=[]
for i in range(len(x)):
    y.append(np.log10(x[i]))
plt.hist(y,bins=40)
plt.yticks(np.arange(0, 150, 50))
ax.set_xticks(Z)
plt.title("t_na")

plt.savefig("SupFig1Btna.pdf")

# %%
x=[]
for i in range(len(S["g_kvhh"])):
    if i==0:
        continue
    ss1=S["g_cav"][i]
    x.append(ss1)
    
fig=plt.figure()
ax = fig.add_subplot(111)
Z=np.linspace(-2,2,3)


y=[]
for i in range(len(x)):
    y.append(np.log10(x[i]))
plt.hist(y,bins=40)
plt.yticks(np.arange(0, 150, 50))
ax.set_xticks(Z)
plt.title("g_cav")

# %%
fig=plt.figure()
ax = fig.add_subplot(111)
Z=np.linspace(-2,2,5)


y=[]
for i in range(len(x)):
    y.append(np.log10(x[i]))
plt.hist(y,bins=40)
plt.yticks(np.arange(0, 150, 50))
ax.set_xticks(Z)

# %%
x=[]
for i in range(len(S["g_kvhh"])):
    if i==0:
        continue
    ss1=S["g_unav"][i]
    x.append(ss1)
fig=plt.figure()
ax = fig.add_subplot(111)
Z=np.linspace(-2,2,5)


y=[]
for i in range(len(x)):
    y.append(np.log10(x[i]))
plt.hist(y,bins=40)
plt.yticks(np.arange(0, 150, 50))
ax.set_xticks(Z)
plt.title("g_unav")
plt.savefig("Sup2_2_1.pdf")

# %%
x=[]
for i in range(len(S["g_kvhh"])):
    if i==0:
        continue
    ss1=S["g_kna"][i]
    x.append(ss1)
fig=plt.figure()
ax = fig.add_subplot(111)
Z=np.linspace(-2,2,5)


y=[]
for i in range(len(x)):
    y.append(np.log10(x[i]))
plt.hist(y,bins=40)
plt.yticks(np.arange(0, 150, 50))
ax.set_xticks(Z)
plt.title("g_kna")
plt.savefig("Sup2_2_2.pdf")

# %%
x=[]
for i in range(len(S["g_kvhh"])):
    if i==0:
        continue
    ss1=S["g_leak"][i]
    x.append(ss1)
fig=plt.figure()
ax = fig.add_subplot(111)
Z=np.linspace(-2,2,5)


y=[]
for i in range(len(x)):
    y.append(np.log10(x[i]))
plt.hist(y,bins=40)
plt.yticks(np.arange(0, 150, 50))
ax.set_xticks(Z)
plt.title("g_leak")
plt.savefig("Sup2_2_3.pdf")

# %%
x=[]
for i in range(len(S["g_kvhh"])):
    if i==0:
        continue
    ss1=S["t_na"][i]

    ss2=""
    sss2=""
    ssss2=""
    for i in range(len(ss1)):
        if(i==0 or i==len(ss1)-1):
            continue
        ss2=ss2+ss1[i]
    ss3=float(ss2)

    ss1=ss3
    x.append(ss1)
fig=plt.figure()
ax = fig.add_subplot(111)
Z=np.linspace(3,4,5)


y=[]
for i in range(len(x)):
    y.append(np.log10(x[i]))
plt.hist(y,bins=40)
plt.yticks(np.arange(0, 150, 50))
ax.set_xticks(Z)
plt.title("t_na")
plt.savefig("Sup2_2_4.pdf")

# %%
x=[]
for i in range(len(S["g_kvhh"])):
    if i==0:
        continue
    ss1=S["x_na"][i]

    ss2=""
    sss2=""
    ssss2=""
    for i in range(len(ss1)):
        if(i==0 or i==len(ss1)-1):
            continue
        ss2=ss2+ss1[i]
    ss3=float(ss2)

    ss1=ss3
    x.append(ss1)

plt.hist(x,bins=40,range=(-45,45))
plt.yticks(np.arange(0, 150, 50))
plt.title("x_na")
plt.savefig("Sup2_2_5.pdf")

# %%
x=[]
for i in range(len(S["g_kvhh"])):
    if i==0:
        continue
    ss1=S["x_na"][i]

    x.append(ss1)
plt.hist(x,bins=40,range=(-45,45))
plt.yticks(np.arange(0, 150, 50))
plt.title("x_na")
plt.savefig("1c.pdf")

# %%
len(x)

# %%
x=[]
for i in range(len(S["g_kvhh"])):
    if i==0:
        continue
    ss1=S["y_na"][i]

    ss2=""
    sss2=""
    ssss2=""
    for i in range(len(ss1)):
        if(i==0 or i==len(ss1)-1):
            continue
        ss2=ss2+ss1[i]
    ss3=float(ss2)

    ss1=ss3
    x.append(ss1)
plt.hist(x,bins=40,range=(-45,45))
plt.yticks(np.arange(0, 150, 50))
plt.title("y_na")
plt.savefig("Sup2_2_6.pdf")

# %%
x=[]
for i in range(len(S["g_kvhh"])):
    if i==0:
        continue
    ss1=S["g_cav"][i]
    x.append(ss1)
fig=plt.figure()
ax = fig.add_subplot(111)
Z=np.linspace(-2,2,5)


y=[]
for i in range(len(x)):
    y.append(np.log10(x[i]))
plt.hist(y,bins=40)
plt.yticks(np.arange(0, 150, 50))
ax.set_xticks(Z)
plt.title("g_cav")
plt.savefig("Sup2_2_7.pdf")

# %%
x=[]
for i in range(len(S["g_kvhh"])):
    if i==0:
        continue
    ss1=S["x_na"][i]

    ss2=""
    sss2=""
    ssss2=""
    for i in range(len(ss1)):
        if(i==0 or i==len(ss1)-1):
            continue
        ss2=ss2+ss1[i]
    ss3=float(ss2)

    ss1=ss3
    
    

    x.append(ss1)

# %%
plt.hist(x,bins=100, range=(-45,45))
plt.title("x_na")
#plt.savefig("x21.png")

# %%
x=[]
for i in range(len(S["g_kvhh"])):
    if i==0:
        continue
    ss1=S["y_na"][i]

    ss2=""
    sss2=""
    ssss2=""
    for i in range(len(ss1)):
        if(i==0 or i==len(ss1)-1):
            continue
        ss2=ss2+ss1[i]
    ss3=float(ss2)

    ss1=ss3
    
    

    x.append(ss1)

# %%
plt.hist(x,bins=100, range=(-45,45))
plt.title("y_na")

#plt.savefig("y21.png")
